# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import nltk
import json
import os
import sys
import time
import operator
#import re
import string
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
###########
ps = PorterStemmer()

# %%
########### Set up Output File
outdir = '..//data//clean_data'

##### Contain 2 column : 1. Replaced name of entity / 2. Real name of entity
reverse_entity = open(os.path.join(outdir,os.path.basename('entity_total.csv')),'w',encoding='utf-8') 

#####
#entity_replaced = open(os.path.join(outdir,os.path.basename('entity_replaced_4.csv')),'w',encoding='utf-8')

# %%
########### Trigger word
triggers_raw = open('..//data//preprocessing/triggers.txt').read().split('\n')[:-1]
triggers = []
for row in triggers_raw :
    triggers.append(ps.stem(row.split('\t')[-1]))
    
triggers = list(set(triggers))

# %%
########### Entity sources

#### Drug synonyms from drugbank
#drugs = json.load(open('..//data/preprocessing/drug_corpus/drug_name_synonyms.json',encoding='utf-8'))
drugs = json.load(open('..//data/preprocessing/drug_corpus/drugs.json',encoding='utf-8'))
#### Herb scientific name and its synonyms (not alias)
#herbs = json.load(open('..//data/preprocessing/herb_corpus/herb_science_synonyms.json',encoding='utf-8'))
herbs = json.load(open('..//data/preprocessing/herb_corpus/herb_syms_total.json',encoding='utf-8'))
#### standard ref without effect
ref_without = json.load(open('..//data/preprocessing/standard_ref/standard_ref_without_effect.json',encoding='utf-8'))

#### standard ref with effect
#ref_effect = open('..//data/preprocessing/standard_ref/standard_ref_effect.csv').read().split('\n')[:-1]

#### Adverse effect corpus
#adverse_effect = json.load(open('..//data/preprocessing/adverse_effect_corpus/adverse_effect.json'))

# %%
########## Create name for entity

###### trigger entity
#trigger_entity = {}
#for each in triggers :
#    trigger_entity[each] = 'trigger_entity'
#    reverse_entity.write('trigger_entity\t%s\n'%each)

###### Drug entity
drug_entity = {}
drugorder = 0
for ID in drugs :
    for drug in drugs[ID] :
        if drug.lower() in herbs or drug.lower() in ref_without :
            break
        drug_entity[drug.lower()] = 'drug_entity_%s'%drugorder
        try :
            reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drug.lower()))
        except :
            drugencode = str(drug.lower()).encode('utf8')
            reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drugencode))
    drugorder+=1

###### Herb entity 
herb_entity = {}
herborder = 0
for herb in herbs :
    #herb_entity[herb.lower()] = 'herb_entity_%s'%herborder
    reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herb.lower()))
    for synonym in herbs[herb] :
        herb_entity[synonym.lower()] = 'herb_entity_%s'%herborder
        try :
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,synonym.lower()))
        except :
            herbencode = str(synonym.lower()).encode('utf8')
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herbencode))
    herborder+=1
    
###### Adverse effect entity
#effect_entity = {}
#effectorder = 0
#for each in adverse_effect :
#    effect_entity[each.lower()] = 'EF_entity_%s'%effectorder
#    try :
#        reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,each.lower()))
#    except :
#        effectencode = str(each.lower()).encode('utf8')
#        reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#    effectorder+=1
    
###### standard ref without effect entity 
for herb in ref_without :
    if herb.lower() not in herb_entity :
        herb_entity[herb.lower()] = 'herb_entity_%s'%herborder
        try :
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herb.lower()))
        except :
            herbencode = str(herb.lower()).encode('utf8')
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herbencode))
        herborder+=1
    for drug in ref_without[herb] :
        if drug.lower() not in drug_entity :
            drug_entity[drug.lower()] = 'drug_entity_%s'%drugorder
            try :
                reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drug.lower()))
            except :
                drugencode = str(drug.lower()).encode('utf8')
                reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drugencode))
            drugorder+=1
            
###### standard ref with effect
''''''
#for row in ref_effect :
#    effect = row.split('\t')[2]
#    ###
#    if effect.lower() not in effect_entity :
#        effect_entity[effect.lower()] = 'EF_entity_%s'%effectorder
#        try :
#            reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effect.lower()))
#        except :
#            effectencode = str(effect.lower()).encode('utf8')
#            reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#        effectorder+=1
#    ###    
#    if len(row.split('\t')) == 4 :
#        effect1 = row.split('\t')[3]
#        if effect1.lower() not in effect_entity :
#            effect_entity[effect1.lower()] = 'EF_entity_%s'%effectorder
#            try :
#                reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effect1.lower()))
#            except :
#                effectencode = str(effect1.lower()).encode('utf8')
#                reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#            effectorder+=1
''''''
######
reverse_entity.close()

# %%
###### remove '\n' from text and merge text
def rmv_n(textdict) :
    begin = time.time()
    text = ''
    print('merge text')
    count = 0
    for each in textdict :
        if len(textdict[each].split('\n')) != 1 :
            new = ''.join(textdict[each].split('\n'))
            text+=new
        else:
            text+= textdict[each]
        if count % 1000 == 0 :
            print('%s / %s'%(count,len(textdict)))
        count+=1
    text = text.lower()
    print(time.time() - begin)
    print('merge text done')
    return text

# %%
###### remove '\n' from text and merge text
def rmv_n(textdict) :
    begin = time.time()
    text = ''
    print('merge text')

    #text = ''.join(''.join(operator.itemgetter(*list(textdict))(textdict)).split('\n')).lower()
    
    #text = ''.join(''.join([textdict[x] for x in list(textdict)]).split('\n')).lower()
    #text =  ''.join([''.join(x.split('\n')) for sublist in textdict for x in sublist ])
    text = ''.join([textdict[x].replace('\n',' ') for x in list(textdict)])
    print(time.time() - begin)
    print('merge text done')
    return text

# %%
###### Entity replacement
def entity_replace(text) :
    ###
    begin = time.time()
    ###
    count = 0
    print('herb')
    for herb in herb_entity :
        if herb in text :
            text = text.replace(' %s '%herb,' %s '%herb_entity[herb])
            #re.sub(herb,herb_entity[herb],text)
            #if herb not in replaced_list :
                #entity_replaced.write('%s\t%s\n'%(herb_entity[herb],herb))
                #replaced_list.append(herb)
        if count % 10000 == 0 :
            print('%s / %s'%(count,len(herb_entity)))
        count+=1
    print('herb done')
    
    ###
    drug_entity_single = {}
    count = 0
    print('drug')
    for drug in drug_entity :
        if drug in text :
            text = text.replace(' %s '%drug,' %s '%drug_entity[drug])
            #re.sub(drug,drug_entity[drug],text)
            #if drug not in replaced_list :
                #entity_replaced.write('%s\t%s\n'%(drug_entity[drug],drug))
                #replaced_list.append(drug)
        #else:
            #drug_entity_single[drug] = drug_entity[drug]
        if count % 10000 == 0 :
            print('%s / %s'%(count,len(drug_entity)))
        count+=1
    print('drug done')
    ###
#    print('effect')
#    count = 0
#    for effect in effect_entity :
#        if effect in text :
#            text = text.replace(effect,' %s '%effect_entity[effect])
#            #re.sub(effect,effect_entity[effect],text)
#            if effect not in replaced_list :
#                entity_replaced.write('%s\t%s\n'%(effect_entity[effect],effect))
#                replaced_list.append(effect)
#        if count % 1000 == 0 :
#            print('%s / %s'%(count,len(drug_entity)))
#        count+=1
#    print('effect done')
    ###
#    for trig in trigger_entity:
#        if trig in text:
#            text = text.replace(trig,' %s '%trigger_entity[trig])
            #re.sub(trig,trigger_entity[trig],text)
#            if trig not in replaced_list :
#                entity_replaced.write('%s\t%s\n'%(trigger_entity[trig],trig))
#                replaced_list.append(effect)
#    print('trigger done')
    print(time.time() - begin)
    print('replace entities done')
    return text

# %%
a = [[1,2,3,4],[4,5,6,7],[3,4,5,6]]
b = [4,5,6,7]
c = [3,4,5,6]

[ [ i for i in each if i in b and i in c ] for each in a]
# Out:
# [[4], [4, 5, 6], [4, 5, 6]]

# %%
######## word processing and word removal
#stop_words = list(set(stopwords.words('english')))
#punctuations = string.punctuation

stop_and_punctuations = list(set(stopwords.words('english'))) + [i for i in string.punctuation ]


def word_processing(text,track,stop_and_punctuations) :
    begin = time.time()
    count = 0
    #outdir = '..//data//clean_data//noun_verb'
    outdir = '..//data//clean_data//'
    subtrack = 0
    ######
    Pos_accept = ['N','V']
    
    ###### Split text into words
    #words = nltk.pos_tag(word_tokenize(text))
    #text = ''
    sentences = [ x for x in TextBlob(text).sentences if len(x.split()) > 3 ]
    total = len(sentences)
    print('Processing %s sentences'%total)
    #######
    sentences_noun_verb = []
    ########
    sentence_noun_verb = []
    ###### Processing
    sentences_noun_verb = [ [word[0] for word in sentence.tags if word[1][0] in Pos_accept and word[0] not in stop_and_punctuations ]  for sentence in sentences ]
    
    ##### 
    print(time.time() - begin)
    print('Word processed done')

    ##### Noun verb
    #outdir = '..//data//clean_data//noun_verb'
    outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
    outfile.write(json.dumps(sentences_noun_verb))
    outfile.close()
    sentences_noun_verb = []

# %%
######## word processing and word removal
def word_processing(text) :
    begin = time.time()
    count = 0

    ###### Create pos_tag accept list and stop words list 
    stop_words = list(set(stopwords.words('english')))
    pos_tag_accept = ['NN','NNS','NNP','NNPS','VB','VBD','VBG','VBN','VBP','VBZ']

    ###### Create entity list 
    reverse_entity = open('..//data/clean_data/entity_total.csv').read().split('\n')[:-1]
    entity_list = []
    for row in reverse_entity :
        entity_list.append(row.split('\t')[0])

    entity_list = list(set(entity_list))

    ###### Split text into sentences
    sentences = TextBlob(text).sentences
    total = len(sentences)
    print('Processing %s sentences'%total)
    sentences_processed = []

    ###### Processing
    for sentence in sentences :          
        words = word_tokenize(str(sentence)) ##### Split sentence into words 
        #####
        if len(set(words).intersection(entity_list)) > 2 : ##### Choose sentence contain more than 2 entities
            for word in words :
                if word in stop_words : ##### Remove stop words
                    words.pop(words.index(word))
                elif len(word) == 1 : ##### Remove punctuation marks
                    words.pop(words.index(word))    
            ###
            tags = nltk.pos_tag(words)
            for tag in tags :
                if tag[0] in entity_list : ##### Save entities
                    pass      
                elif tag[1] not in pos_tag_accept : ##### Remove words which are not noun,verb, and adjective 
                    words.pop(words.index(tag[0]))
            ###
            if len(words) > 3 : ###### Save processed sentence
                sentences_processed.append(words)
        ###
        if count % 10000 == 0 :
            print('Processed %s sentences'%count)
        count+=1

    ##### 
    print(time.time() - begin)
    print('Word processed done')
    return sentences_processed

# %%
len(os.listdir('..//data/abstract_full/')
# Out:
# 60

# %%
########### Make outdir
os.system('mkdir "..//data//clean_data//noun_verb"')
########### Text source
text_list = os.listdir('..//data/abstract_full_1/')[731:1065]
#text_list = ['abstract_00.json']
count = 0
track = 731
#replaced_list = []
textdict = {}
#for file in text_list :
#for i in range(len(text_list)) :
for file in text_list :
    textdict = json.load(open('../data/abstract_full_1/%s'%file))
    #####
    print('Processing loop %s'%track)
    text = rmv_n(textdict).lower()
    textdict = []
    #####
    print('step 1')
    text = entity_replace(text)
    #####
    print('step 2')
    sentences_processed = word_processing(text,track,stop_and_punctuations)
    text = ''
    #####
    ##### 
    track+=1

#########


#####
#entity_replaced.close()
# Out:
# Processing loop 731
# merge text
# 0.03500199317932129
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 833.051750421524
# replace entities done
# step 2
# Processing 72772 sentences
# 1426.5797140598297
# Word processed done
# Processing loop 732
# merge text
# 0.04950356483459473
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 823.6382350921631
# replace entities done
# step 2
# Processing 72298 sentences
# 1382.6110138893127
# Word processed done
# Processing loop 733
# merge text
# 0.03500199317932129
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 782.3729419708252
# replace entities done
# step 2
# Processing 69870 sentences
# 1246.684026479721
# Word processed done
# Processing loop 734
# merge text
# 0.04000496864318848
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 581.5840585231781
# replace entities done
# step 2
# Processing 50623 sentences
# 967.146871805191
# Word processed done
# Processing loop 735
# merge text
# 0.056006431579589844
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 943.4356868267059
# replace entities done
# step 2
# Processing 73281 sentences
# 1492.921594619751
# Word processed done
# Processing loop 736
# merge text
# 0.07900476455688477
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 932.8563725948334
# replace entities done
# step 2
# Processing 75005 sentences
# 1421.1582355499268
# Word processed done
# Processing loop 737
# merge text
# 0.049002647399902344
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1050.3922634124756
# replace entities done
# step 2
# Processing 73006 sentences
# 1351.675392627716
# Word processed done
# Processing loop 738
# merge text
# 0.12151479721069336
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1034.9775788784027
# replace entities done
# step 2
# Processing 73169 sentences
# 1500.4477996826172
# Word processed done
# Processing loop 739
# merge text
# 0.1260073184967041
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1084.1785757541656
# replace entities done
# step 2
# Processing 72852 sentences
# 1309.9022884368896
# Word processed done
# Processing loop 740
# merge text
# 0.07200407981872559
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 877.6923019886017
# replace entities done
# step 2
# Processing 74314 sentences
# 1242.5806632041931
# Word processed done
# Processing loop 741
# merge text
# 0.0980081558227539
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 883.7763149738312
# replace entities done
# step 2
# Processing 73605 sentences
# 1222.7977411746979
# Word processed done
# Processing loop 742
# merge text
# 0.04800605773925781
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 895.4754552841187
# replace entities done
# step 2
# Processing 71499 sentences
# 1383.1999382972717
# Word processed done
# Processing loop 743
# merge text
# 0.0630035400390625
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 981.0989348888397
# replace entities done
# step 2
# Processing 73046 sentences
# 1416.6235756874084
# Word processed done
# Processing loop 744
# merge text
# 0.07100439071655273
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1016.1235175132751
# replace entities done
# step 2
# Processing 74194 sentences
# 1227.2617094516754
# Word processed done
# Processing loop 745
# merge text
# 0.11900663375854492
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1003.8071851730347
# replace entities done
# step 2
# Processing 72925 sentences
# 1178.7544627189636
# Word processed done
# Processing loop 746
# merge text
# 0.06400370597839355
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1003.7106356620789
# replace entities done
# step 2
# Processing 71720 sentences
# 1129.891860485077
# Word processed done
# Processing loop 747
# merge text
# 0.02300119400024414
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 705.318452835083
# replace entities done
# step 2
# Processing 51062 sentences
# 810.4050104618073
# Word processed done
# Processing loop 748
# merge text
# 0.03300213813781738
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 584.7780828475952
# replace entities done
# step 2
# Processing 56763 sentences
# 1127.6451578140259
# Word processed done
# Processing loop 749
# merge text
# 0.031001806259155273
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 556.8819718360901
# replace entities done
# step 2
# Processing 56296 sentences
# 1073.5042061805725
# Word processed done
# Processing loop 750
# merge text
# 0.047003746032714844
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 656.2887790203094
# replace entities done
# step 2
# Processing 56101 sentences
# 1058.2370183467865
# Word processed done
# Processing loop 751
# merge text
# 0.11451458930969238
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 986.7510526180267
# replace entities done
# step 2
# Processing 56800 sentences
# 1065.1649584770203
# Word processed done
# Processing loop 752
# merge text
# 0.05700325965881348
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 836.6480374336243
# replace entities done
# step 2
# Processing 70941 sentences
# 1165.1417360305786
# Word processed done
# Processing loop 753
# merge text
# 0.10600590705871582
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 786.0990574359894
# replace entities done
# step 2
# Processing 72700 sentences
# 1186.3571093082428
# Word processed done
# Processing loop 754
# merge text
# 0.1480088233947754
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 807.6302144527435
# replace entities done
# step 2
# Processing 72420 sentences
# 1201.8430020809174
# Word processed done
# Processing loop 755
# merge text
# 0.05050516128540039
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 753.1640315055847
# replace entities done
# step 2
# Processing 73445 sentences
# 1303.1069571971893
# Word processed done
# Processing loop 756
# merge text
# 0.05600309371948242
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 726.0640199184418
# replace entities done
# step 2
# Processing 73338 sentences
# 1302.3416974544525
# Word processed done
# Processing loop 757
# merge text
# 0.04600262641906738
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 696.7960300445557
# replace entities done
# step 2
# Processing 71562 sentences
# 1255.0091183185577
# Word processed done
# Processing loop 758
# merge text
# 0.04000210762023926
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 758.6327385902405
# replace entities done
# step 2
# Processing 79462 sentences
# 1391.5773570537567
# Word processed done
# Processing loop 759
# merge text
# 0.03800225257873535
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 735.9153757095337
# replace entities done
# step 2
# Processing 74937 sentences
# 1450.2423124313354
# Word processed done
# Processing loop 760
# merge text
# 0.054003000259399414
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 716.9134731292725
# replace entities done
# step 2
# Processing 69442 sentences
# 1184.632286787033
# Word processed done
# Processing loop 761
# merge text
# 0.03800201416015625
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 796.7515189647675
# replace entities done
# step 2
# Processing 73073 sentences
# 1195.3255922794342
# Word processed done
# Processing loop 762
# merge text
# 0.05300283432006836
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 825.1901376247406
# replace entities done
# step 2
# Processing 72036 sentences
# 1154.9053115844727
# Word processed done
# Processing loop 763
# merge text
# 0.05700325965881348
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 797.5400500297546
# replace entities done
# step 2
# Processing 73293 sentences
# 1183.6930930614471
# Word processed done
# Processing loop 764
# merge text
# 0.06500506401062012
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 904.1429069042206
# replace entities done
# step 2
# Processing 71948 sentences
# 1163.7188129425049
# Word processed done
# Processing loop 765
# merge text
# 0.06750845909118652
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 805.0788242816925
# replace entities done
# step 2
# Processing 73284 sentences
# 1395.3610441684723
# Word processed done
# Processing loop 766
# merge text
# 0.034001827239990234
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 685.7047441005707
# replace entities done
# step 2
# Processing 48401 sentences
# 861.408864736557
# Word processed done
# Processing loop 767
# merge text
# 0.0630037784576416
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 766.077002286911
# replace entities done
# step 2
# Processing 66424 sentences
# 1301.2925362586975
# Word processed done
# Processing loop 768
# merge text
# 0.07300424575805664
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 769.4686880111694
# replace entities done
# step 2
# Processing 73335 sentences
# 1496.6137690544128
# Word processed done
# Processing loop 769
# merge text
# 0.1510162353515625
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 800.103465795517
# replace entities done
# step 2
# Processing 74027 sentences
# 1541.8401033878326
# Word processed done
# Processing loop 770
# merge text
# 0.0765080451965332
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 669.2804734706879
# replace entities done
# step 2
# Processing 74424 sentences
# 1385.3311002254486
# Word processed done
# Processing loop 771
# merge text
# 0.0630035400390625
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 775.4065680503845
# replace entities done
# step 2
# Processing 72042 sentences
# 1439.902027130127
# Word processed done
# Processing loop 772
# merge text
# 0.054003238677978516
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 831.0867240428925
# replace entities done
# step 2
# Processing 73707 sentences
# 1575.1087765693665
# Word processed done
# Processing loop 773
# merge text
# 0.24302363395690918
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1021.0170571804047
# replace entities done
# step 2
# Processing 72163 sentences
# 3287.6350462436676
# Word processed done
# Processing loop 774
# merge text
# 0.07400941848754883
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1128.2118182182312
# replace entities done
# step 2
# Processing 72049 sentences
# 3311.7294635772705
# Word processed done
# Processing loop 775
# merge text
# 0.0615079402923584
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 891.4930338859558
# replace entities done
# step 2
# Processing 66822 sentences
# 2394.6996099948883
# Word processed done
# Processing loop 776
# merge text
# 0.05300331115722656
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 808.8611872196198
# replace entities done
# step 2
# Processing 69887 sentences
# 1735.7861411571503
# Word processed done
# Processing loop 777
# merge text
# 0.054003000259399414
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 764.640704870224
# replace entities done
# step 2
# Processing 72425 sentences
# 1229.5411071777344
# Word processed done
# Processing loop 778
# merge text
# 0.049002647399902344
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 701.8616824150085
# replace entities done
# step 2
# Processing 69695 sentences
# 1202.1666069030762
# Word processed done
# Processing loop 779
# merge text
# 0.046002864837646484
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 620.2046992778778
# replace entities done
# step 2
# Processing 73064 sentences
# 1253.904633283615
# Word processed done
# Processing loop 780
# merge text
# 0.047002553939819336
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 770.3413410186768
# replace entities done
# step 2
# Processing 72249 sentences
# 1195.362342119217
# Word processed done
# Processing loop 781
# merge text
# 0.10300755500793457
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 872.228128194809
# replace entities done
# step 2
# Processing 72108 sentences
# 1160.5389614105225
# Word processed done
# Processing loop 782
# merge text
# 0.07750511169433594
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 937.1187329292297
# replace entities done
# step 2
# Processing 73021 sentences
# 1200.015991449356
# Word processed done
# Processing loop 783
# merge text
# 0.05500316619873047
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 782.9974565505981
# replace entities done
# step 2
# Processing 68876 sentences
# 1180.2951245307922
# Word processed done
# Processing loop 784
# merge text
# 0.0680086612701416
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 814.159547328949
# replace entities done
# step 2
# Processing 71684 sentences
# 1189.6374979019165
# Word processed done
# Processing loop 785
# merge text
# 0.04200243949890137
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 873.8400673866272
# replace entities done
# step 2
# Processing 74691 sentences
# 1241.47238945961
# Word processed done
# Processing loop 786
# merge text
# 0.07700443267822266
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 884.2220630645752
# replace entities done
# step 2
# Processing 73641 sentences
# 1204.9543843269348
# Word processed done
# Processing loop 787
# merge text
# 0.13100767135620117
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 894.8146014213562
# replace entities done
# step 2
# Processing 73722 sentences
# 1209.4744775295258
# Word processed done
# Processing loop 788
# merge text
# 0.0890052318572998
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 918.1270949840546
# replace entities done
# step 2
# Processing 73932 sentences
# 1398.0926382541656
# Word processed done
# Processing loop 789
# merge text
# 0.08800745010375977
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 928.5780689716339
# replace entities done
# step 2
# Processing 71279 sentences
# 1214.7972919940948
# Word processed done
# Processing loop 790
# merge text
# 0.039002180099487305
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 706.8518409729004
# replace entities done
# step 2
# Processing 76920 sentences
# 1528.5525720119476
# Word processed done
# Processing loop 791
# merge text
# 0.08200454711914062
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 945.19207239151
# replace entities done
# step 2
# Processing 73962 sentences

# %%
textdict = []

# %%
########### Make outdir
#os.system('mkdir "..//data//clean_data//only_noun"')
#os.system('mkdir "..//data//clean_data//only_entity"')
#os.system('mkdir "..//data//clean_data//without_adjective"')
#os.system('mkdir "..//data//clean_data//full_sentence"')
os.system('mkdir "..//data//clean_data//noun_verb"')
########### Text source
#text_list = os.listdir('..//data/preprocessing/text_extract/')
text_list = os.listdir('..//data/abstract_full/')[:]
#text_list = ['abtract_list_26.json']
count = 0
track = 0
#replaced_list = []
textdict = []
#for file in text_list :
#for i in range(len(text_list)) :
while text_list != [] :
    #####
    start = 0
    if len(text_list) > 5 :
        for num in range(5) :
            if start == 0 :
                #textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
                textdict = json.load(open('..//data/abstract_full/%s'%text_list[num]))
                start = 1
            else :
                textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
        [text_list.pop(0) for i in range(5)]
    else :
        for num in range(len(text_list)) :
            if start == 0 :
                #textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
                textdict = json.load(open('..//data//abstract_full/%s'%text_list[num]))
                start = 1
            else :
                textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
        [text_list.pop(0) for i in range(len(text_list))]
    #####
    print('Processing loop %s'%track)
    text = rmv_n(textdict)
    textdict = []
    #####
    print('step 1')
    (text,replaced_list) = entity_replace(text,replaced_list)
    #####
    print('step 2')
    sentences_processed = word_processing(text,track,stop_words,punctuations)
    text = ''
    #####
    ##### 
    track+=1

#########


#####
#entity_replaced.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-035601df330d> in <module>()
#      25                 start = 1
#      26             else :
# ---> 27                 textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
#      28         [text_list.pop(0) for i in range(5)]
#      29     else :
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'dict'

# %%
########### Text source
#text_list = os.listdir('..//data/preprocessing/text_extract/')
text_list = ['text_extract_100.json']
count = 0
track = 0
replaced_list = []
textdict = []
for file in text_list :
    if count == 0 :
        textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
        count+=1
    elif count < 8 :
        textdict.update(json.load(open('..//data//preprocessing//text_extract//%s'%file)))
        count+=1
    elif count == 8 :
        textdict.update(json.load(open('..//data//preprocessing//text_extract//%s'%file)))
        count = 0
        #####
        print('Processing loop %s'%track)
        text = rmv_n(textdict)
        textdict = []
        #####
        print('step 1')
        (text,replaced_list) = entity_replace(text,replaced_list)
        #####
        print('step 2')
        sentences_processed = word_processing(text)
        text = ''
        #####
        ##### List of processed sentences
        outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
        outfile.write(json.dumps(sentences_processed))
        outfile.close()
        track+=1
        sentences_processed = []
        
#########
print('Processing loop %s'%track)
text = rmv_n(textdict)
textdict = []
#####
print('step 1')
(text,replaced_list) = entity_replace(text,replaced_list)
#####
print('step 2')
sentences_processed = word_processing(text)
text = ''
#####
##### List of processed sentences
outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
outfile.write(json.dumps(sentences_processed))
outfile.close()

#####
entity_replaced.close()
# Out:
# Processing loop 0
# merge text
# 0.1980113983154297
# merge text done
# step 1
# herb
# 0 / 30820
# 1000 / 30820
# 2000 / 30820
# 3000 / 30820
# 4000 / 30820
# 5000 / 30820
# 6000 / 30820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-ceb61dfe55b6> in <module>()
#      41 #####
#      42 print('step 1')
# ---> 43 (text,replaced_list) = entity_replace(text,replaced_list)
#      44 #####
#      45 print('step 2')
#
# <ipython-input-121-9617de803cfa> in entity_replace(text, replaced_list)
#      15         if count % 1000 == 0 :
#      16             print('%s / %s'%(count,len(herb_entity)))
# ---> 17         count+=1
#      18     print('herb done')
#      19
#
# KeyboardInterrupt:

# %%
entity_replaced.close()
