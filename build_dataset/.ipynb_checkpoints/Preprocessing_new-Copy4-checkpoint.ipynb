# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import nltk
import json
import os
import sys
import time
import operator
#import re
import string
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
###########
ps = PorterStemmer()

# %%
########### Set up Output File
outdir = '..//data//clean_data'

##### Contain 2 column : 1. Replaced name of entity / 2. Real name of entity
reverse_entity = open(os.path.join(outdir,os.path.basename('entity_total.csv')),'w',encoding='utf-8') 

#####
#entity_replaced = open(os.path.join(outdir,os.path.basename('entity_replaced_4.csv')),'w',encoding='utf-8')

# %%
########### Trigger word
triggers_raw = open('..//data//preprocessing/triggers.txt').read().split('\n')[:-1]
triggers = []
for row in triggers_raw :
    triggers.append(ps.stem(row.split('\t')[-1]))
    
triggers = list(set(triggers))

# %%
########### Entity sources

#### Drug synonyms from drugbank
#drugs = json.load(open('..//data/preprocessing/drug_corpus/drug_name_synonyms.json',encoding='utf-8'))
drugs = json.load(open('..//data/preprocessing/drug_corpus/drugs.json',encoding='utf-8'))
#### Herb scientific name and its synonyms (not alias)
#herbs = json.load(open('..//data/preprocessing/herb_corpus/herb_science_synonyms.json',encoding='utf-8'))
herbs = json.load(open('..//data/preprocessing/herb_corpus/herb_syms_total.json',encoding='utf-8'))
#### standard ref without effect
ref_without = json.load(open('..//data/preprocessing/standard_ref/standard_ref_without_effect.json',encoding='utf-8'))

#### standard ref with effect
#ref_effect = open('..//data/preprocessing/standard_ref/standard_ref_effect.csv').read().split('\n')[:-1]

#### Adverse effect corpus
#adverse_effect = json.load(open('..//data/preprocessing/adverse_effect_corpus/adverse_effect.json'))

# %%
########## Create name for entity

###### trigger entity
#trigger_entity = {}
#for each in triggers :
#    trigger_entity[each] = 'trigger_entity'
#    reverse_entity.write('trigger_entity\t%s\n'%each)

###### Drug entity
drug_entity = {}
drugorder = 0
for ID in drugs :
    for drug in drugs[ID] :
        if drug.lower() in herbs or drug.lower() in ref_without :
            break
        drug_entity[drug.lower()] = 'drug_entity_%s'%drugorder
        try :
            reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drug.lower()))
        except :
            drugencode = str(drug.lower()).encode('utf8')
            reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drugencode))
    drugorder+=1

###### Herb entity 
herb_entity = {}
herborder = 0
for herb in herbs :
    #herb_entity[herb.lower()] = 'herb_entity_%s'%herborder
    reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herb.lower()))
    for synonym in herbs[herb] :
        herb_entity[synonym.lower()] = 'herb_entity_%s'%herborder
        try :
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,synonym.lower()))
        except :
            herbencode = str(synonym.lower()).encode('utf8')
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herbencode))
    herborder+=1
    
###### Adverse effect entity
#effect_entity = {}
#effectorder = 0
#for each in adverse_effect :
#    effect_entity[each.lower()] = 'EF_entity_%s'%effectorder
#    try :
#        reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,each.lower()))
#    except :
#        effectencode = str(each.lower()).encode('utf8')
#        reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#    effectorder+=1
    
###### standard ref without effect entity 
for herb in ref_without :
    if herb.lower() not in herb_entity :
        herb_entity[herb.lower()] = 'herb_entity_%s'%herborder
        try :
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herb.lower()))
        except :
            herbencode = str(herb.lower()).encode('utf8')
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herbencode))
        herborder+=1
    for drug in ref_without[herb] :
        if drug.lower() not in drug_entity :
            drug_entity[drug.lower()] = 'drug_entity_%s'%drugorder
            try :
                reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drug.lower()))
            except :
                drugencode = str(drug.lower()).encode('utf8')
                reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drugencode))
            drugorder+=1
            
###### standard ref with effect
''''''
#for row in ref_effect :
#    effect = row.split('\t')[2]
#    ###
#    if effect.lower() not in effect_entity :
#        effect_entity[effect.lower()] = 'EF_entity_%s'%effectorder
#        try :
#            reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effect.lower()))
#        except :
#            effectencode = str(effect.lower()).encode('utf8')
#            reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#        effectorder+=1
#    ###    
#    if len(row.split('\t')) == 4 :
#        effect1 = row.split('\t')[3]
#        if effect1.lower() not in effect_entity :
#            effect_entity[effect1.lower()] = 'EF_entity_%s'%effectorder
#            try :
#                reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effect1.lower()))
#            except :
#                effectencode = str(effect1.lower()).encode('utf8')
#                reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#            effectorder+=1
''''''
######
reverse_entity.close()

# %%
###### remove '\n' from text and merge text
def rmv_n(textdict) :
    begin = time.time()
    text = ''
    print('merge text')
    count = 0
    for each in textdict :
        if len(textdict[each].split('\n')) != 1 :
            new = ''.join(textdict[each].split('\n'))
            text+=new
        else:
            text+= textdict[each]
        if count % 1000 == 0 :
            print('%s / %s'%(count,len(textdict)))
        count+=1
    text = text.lower()
    print(time.time() - begin)
    print('merge text done')
    return text

# %%
###### remove '\n' from text and merge text
def rmv_n(textdict) :
    begin = time.time()
    text = ''
    print('merge text')

    #text = ''.join(''.join(operator.itemgetter(*list(textdict))(textdict)).split('\n')).lower()
    
    #text = ''.join(''.join([textdict[x] for x in list(textdict)]).split('\n')).lower()
    #text =  ''.join([''.join(x.split('\n')) for sublist in textdict for x in sublist ])
    text = ''.join([textdict[x].replace('\n',' ') for x in list(textdict)])
    print(time.time() - begin)
    print('merge text done')
    return text

# %%
###### Entity replacement
def entity_replace(text) :
    ###
    begin = time.time()
    ###
    count = 0
    print('herb')
    for herb in herb_entity :
        if herb in text :
            text = text.replace(' %s '%herb,' %s '%herb_entity[herb])
            #re.sub(herb,herb_entity[herb],text)
            #if herb not in replaced_list :
                #entity_replaced.write('%s\t%s\n'%(herb_entity[herb],herb))
                #replaced_list.append(herb)
        if count % 10000 == 0 :
            print('%s / %s'%(count,len(herb_entity)))
        count+=1
    print('herb done')
    
    ###
    drug_entity_single = {}
    count = 0
    print('drug')
    for drug in drug_entity :
        if drug in text :
            text = text.replace(' %s '%drug,' %s '%drug_entity[drug])
            #re.sub(drug,drug_entity[drug],text)
            #if drug not in replaced_list :
                #entity_replaced.write('%s\t%s\n'%(drug_entity[drug],drug))
                #replaced_list.append(drug)
        #else:
            #drug_entity_single[drug] = drug_entity[drug]
        if count % 10000 == 0 :
            print('%s / %s'%(count,len(drug_entity)))
        count+=1
    print('drug done')
    ###
#    print('effect')
#    count = 0
#    for effect in effect_entity :
#        if effect in text :
#            text = text.replace(effect,' %s '%effect_entity[effect])
#            #re.sub(effect,effect_entity[effect],text)
#            if effect not in replaced_list :
#                entity_replaced.write('%s\t%s\n'%(effect_entity[effect],effect))
#                replaced_list.append(effect)
#        if count % 1000 == 0 :
#            print('%s / %s'%(count,len(drug_entity)))
#        count+=1
#    print('effect done')
    ###
#    for trig in trigger_entity:
#        if trig in text:
#            text = text.replace(trig,' %s '%trigger_entity[trig])
            #re.sub(trig,trigger_entity[trig],text)
#            if trig not in replaced_list :
#                entity_replaced.write('%s\t%s\n'%(trigger_entity[trig],trig))
#                replaced_list.append(effect)
#    print('trigger done')
    print(time.time() - begin)
    print('replace entities done')
    return text

# %%
a = [[1,2,3,4],[4,5,6,7],[3,4,5,6]]
b = [4,5,6,7]
c = [3,4,5,6]

[ [ i for i in each if i in b and i in c ] for each in a]
# Out:
# [[4], [4, 5, 6], [4, 5, 6]]

# %%
######## word processing and word removal
#stop_words = list(set(stopwords.words('english')))
#punctuations = string.punctuation

stop_and_punctuations = list(set(stopwords.words('english'))) + [i for i in string.punctuation ]


def word_processing(text,track,stop_and_punctuations) :
    begin = time.time()
    count = 0
    #outdir = '..//data//clean_data//noun_verb'
    outdir = '..//data//clean_data//'
    subtrack = 0
    ######
    Pos_accept = ['N','V']
    
    ###### Split text into words
    #words = nltk.pos_tag(word_tokenize(text))
    #text = ''
    sentences = [ x for x in TextBlob(text).sentences if len(x.split()) > 3 ]
    total = len(sentences)
    print('Processing %s sentences'%total)
    #######
    sentences_noun_verb = []
    ########
    sentence_noun_verb = []
    ###### Processing
    sentences_noun_verb = [ [word[0] for word in sentence.tags if word[1][0] in Pos_accept and word[0] not in stop_and_punctuations ]  for sentence in sentences ]
    
    ##### 
    print(time.time() - begin)
    print('Word processed done')

    ##### Noun verb
    #outdir = '..//data//clean_data//noun_verb'
    outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
    outfile.write(json.dumps(sentences_noun_verb))
    outfile.close()
    sentences_noun_verb = []

# %%
######## word processing and word removal
def word_processing(text) :
    begin = time.time()
    count = 0

    ###### Create pos_tag accept list and stop words list 
    stop_words = list(set(stopwords.words('english')))
    pos_tag_accept = ['NN','NNS','NNP','NNPS','VB','VBD','VBG','VBN','VBP','VBZ']

    ###### Create entity list 
    reverse_entity = open('..//data/clean_data/entity_total.csv').read().split('\n')[:-1]
    entity_list = []
    for row in reverse_entity :
        entity_list.append(row.split('\t')[0])

    entity_list = list(set(entity_list))

    ###### Split text into sentences
    sentences = TextBlob(text).sentences
    total = len(sentences)
    print('Processing %s sentences'%total)
    sentences_processed = []

    ###### Processing
    for sentence in sentences :          
        words = word_tokenize(str(sentence)) ##### Split sentence into words 
        #####
        if len(set(words).intersection(entity_list)) > 2 : ##### Choose sentence contain more than 2 entities
            for word in words :
                if word in stop_words : ##### Remove stop words
                    words.pop(words.index(word))
                elif len(word) == 1 : ##### Remove punctuation marks
                    words.pop(words.index(word))    
            ###
            tags = nltk.pos_tag(words)
            for tag in tags :
                if tag[0] in entity_list : ##### Save entities
                    pass      
                elif tag[1] not in pos_tag_accept : ##### Remove words which are not noun,verb, and adjective 
                    words.pop(words.index(tag[0]))
            ###
            if len(words) > 3 : ###### Save processed sentence
                sentences_processed.append(words)
        ###
        if count % 10000 == 0 :
            print('Processed %s sentences'%count)
        count+=1

    ##### 
    print(time.time() - begin)
    print('Word processed done')
    return sentences_processed

# %%
len(os.listdir('..//data/abstract_full/')
# Out:
# 60

# %%
########### Make outdir
os.system('mkdir "..//data//clean_data//noun_verb"')
########### Text source
text_list = os.listdir('..//data/abstract_full_1/')[1420:]
#text_list = ['abstract_00.json']
count = 0
track = 1420
#replaced_list = []
textdict = {}
#for file in text_list :
#for i in range(len(text_list)) :
for file in text_list :
    textdict = json.load(open('../data/abstract_full_1/%s'%file))
    #####
    print('Processing loop %s'%track)
    text = rmv_n(textdict).lower()
    textdict = []
    #####
    print('step 1')
    text = entity_replace(text)
    #####
    print('step 2')
    sentences_processed = word_processing(text,track,stop_and_punctuations)
    text = ''
    #####
    ##### 
    track+=1

#########


#####
#entity_replaced.close()
# Out:
# Processing loop 1420
# merge text
# 0.07400941848754883
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1155.2333891391754
# replace entities done
# step 2
# Processing 54540 sentences
# 1775.2210981845856
# Word processed done
# Processing loop 1421
# merge text
# 0.026001453399658203
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1002.7258067131042
# replace entities done
# step 2
# Processing 57466 sentences
# 1707.4556760787964
# Word processed done
# Processing loop 1422
# merge text
# 0.020000219345092773
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 797.8285574913025
# replace entities done
# step 2
# Processing 57888 sentences
# 2204.7343163490295
# Word processed done
# Processing loop 1423
# merge text
# 0.08500480651855469
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 876.6492533683777
# replace entities done
# step 2
# Processing 63562 sentences
# 1915.9352505207062
# Word processed done
# Processing loop 1424
# merge text
# 0.14451837539672852
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1189.579796552658
# replace entities done
# step 2
# Processing 72402 sentences
# 2398.0839071273804
# Word processed done
# Processing loop 1425
# merge text
# 0.31902241706848145
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1437.445630311966
# replace entities done
# step 2
# Processing 75369 sentences
# 2257.4551672935486
# Word processed done
# Processing loop 1426
# merge text
# 0.32804179191589355
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 2003.036218881607
# replace entities done
# step 2
# Processing 76921 sentences
# 4801.712212562561
# Word processed done
# Processing loop 1427
# merge text
# 0.5350308418273926
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1603.0741159915924
# replace entities done
# step 2
# Processing 73620 sentences
# 2857.0589497089386
# Word processed done
# Processing loop 1428
# merge text
# 0.44902563095092773
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1404.3822829723358
# replace entities done
# step 2
# Processing 71578 sentences
# 1855.3735301494598
# Word processed done
# Processing loop 1429
# merge text
# 0.8950345516204834
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1471.0520379543304
# replace entities done
# step 2
# Processing 72572 sentences
# 1900.4057438373566
# Word processed done
# Processing loop 1430
# merge text
# 0.5490214824676514
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1529.4673202037811
# replace entities done
# step 2
# Processing 75247 sentences
# 5098.593504667282
# Word processed done
# Processing loop 1431
# merge text
# 0.30101728439331055
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1357.166123867035
# replace entities done
# step 2
# Processing 74570 sentences
# 1779.0900192260742
# Word processed done
# Processing loop 1432
# merge text
# 0.08999991416931152
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1099.1378438472748
# replace entities done
# step 2
# Processing 55128 sentences
# 1398.262950181961
# Word processed done
# Processing loop 1433
# merge text
# 0.09000015258789062
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1061.5434517860413
# replace entities done
# step 2
# Processing 72382 sentences
# 1881.6745088100433
# Word processed done
# Processing loop 1434
# merge text
# 0.3040022850036621
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 495.71251106262207
# replace entities done
# step 2
# Processing 47626 sentences
# 1382.0554058551788
# Word processed done
# Processing loop 1435
# merge text
# 0.08600258827209473
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 548.2053835391998
# replace entities done
# step 2
# Processing 53944 sentences
# 1337.2797329425812
# Word processed done
# Processing loop 1436
# merge text
# 0.08400487899780273
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1084.8044583797455
# replace entities done
# step 2
# Processing 72193 sentences
# 2279.513652086258
# Word processed done
# Processing loop 1437
# merge text
# 0.15101003646850586
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 969.0661659240723
# replace entities done
# step 2
# Processing 75811 sentences
# 2801.87624001503
# Word processed done
# Processing loop 1438
# merge text
# 0.49956369400024414
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1586.1803658008575
# replace entities done
# step 2
# Processing 76669 sentences
# 2736.5158574581146
# Word processed done
# Processing loop 1439
# merge text
# 1.8461055755615234
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1514.4920210838318
# replace entities done
# step 2
# Processing 70679 sentences
# 3311.54438829422
# Word processed done
# Processing loop 1440
# merge text
# 0.8730497360229492
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1266.944747686386
# replace entities done
# step 2
# Processing 73752 sentences
# 2837.5559294223785
# Word processed done
# Processing loop 1441
# merge text
# 0.8280472755432129
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1151.8838241100311
# replace entities done
# step 2
# Processing 74745 sentences
# 3000.245547771454
# Word processed done
# Processing loop 1442
# merge text
# 0.4320549964904785
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1503.8458585739136
# replace entities done
# step 2
# Processing 74203 sentences
# 2837.714812517166
# Word processed done
# Processing loop 1443
# merge text
# 0.1000056266784668
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 857.6197829246521
# replace entities done
# step 2
# Processing 70766 sentences
# 1382.7446734905243
# Word processed done
# Processing loop 1444
# merge text
# 0.09750580787658691
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 899.9094212055206
# replace entities done
# step 2
# Processing 72237 sentences
# 1310.080150127411
# Word processed done
# Processing loop 1445
# merge text
# 0.25951528549194336
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 855.0318348407745
# replace entities done
# step 2
# Processing 74911 sentences
# 1311.1554625034332
# Word processed done
# Processing loop 1446
# merge text
# 0.1495189666748047
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 756.104775428772
# replace entities done
# step 2
# Processing 73621 sentences
# 1311.10520029068
# Word processed done
# Processing loop 1447
# merge text
# 0.1150064468383789
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 834.7271249294281
# replace entities done
# step 2
# Processing 74073 sentences
# 1479.303421497345
# Word processed done
# Processing loop 1448
# merge text
# 0.08200454711914062
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 807.9463391304016
# replace entities done
# step 2
# Processing 73639 sentences
# 1460.9808819293976
# Word processed done
# Processing loop 1449
# merge text
# 0.04200243949890137
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 768.2476994991302
# replace entities done
# step 2
# Processing 71062 sentences
# 1283.577938079834
# Word processed done
# Processing loop 1450
# merge text
# 0.04600262641906738
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 778.4915080070496
# replace entities done
# step 2
# Processing 71976 sentences
# 1589.5257029533386
# Word processed done
# Processing loop 1451
# merge text
# 0.028001785278320312
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 632.5723757743835
# replace entities done
# step 2
# Processing 55465 sentences
# 1197.5940799713135
# Word processed done
# Processing loop 1452
# merge text
# 0.05400347709655762
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 652.5794267654419
# replace entities done
# step 2
# Processing 55530 sentences
# 1047.452091217041
# Word processed done
# Processing loop 1453
# merge text
# 0.039002418518066406
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 904.0963170528412
# replace entities done
# step 2
# Processing 58862 sentences
# 1054.6148688793182
# Word processed done
# Processing loop 1454
# merge text
# 0.09400558471679688
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1042.8149495124817
# replace entities done
# step 2
# Processing 75617 sentences
# 1572.0216932296753
# Word processed done
# Processing loop 1455
# merge text
# 0.13300776481628418
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 967.6428370475769
# replace entities done
# step 2
# Processing 59451 sentences
# 1000.3294525146484
# Word processed done
# Processing loop 1456
# merge text
# 0.12800860404968262
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 980.4867460727692
# replace entities done
# step 2
# Processing 74375 sentences
# 1192.9447712898254
# Word processed done
# Processing loop 1457
# merge text
# 0.10700631141662598
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 949.7827055454254
# replace entities done
# step 2
# Processing 74847 sentences
# 1218.3483002185822
# Word processed done
# Processing loop 1458
# merge text
# 0.042002201080322266
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 962.9943406581879
# replace entities done
# step 2
# Processing 74278 sentences
# 1421.5918204784393
# Word processed done
# Processing loop 1459
# merge text
# 0.10900640487670898
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 992.3609218597412
# replace entities done
# step 2
# Processing 72432 sentences
# 1415.0558426380157
# Word processed done
# Processing loop 1460
# merge text
# 0.17901015281677246
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 997.575944185257
# replace entities done
# step 2
# Processing 71332 sentences
# 1208.4451355934143
# Word processed done
# Processing loop 1461
# merge text
# 0.32701873779296875
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1009.3172326087952
# replace entities done
# step 2
# Processing 74732 sentences
# 1243.2499668598175
# Word processed done
# Processing loop 1462
# merge text
# 0.13100767135620117
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1032.710649728775
# replace entities done
# step 2
# Processing 76643 sentences
# 1236.0328540802002
# Word processed done
# Processing loop 1463
# merge text
# 0.26001834869384766
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 918.4296498298645
# replace entities done
# step 2
# Processing 70974 sentences
# 1127.206870317459
# Word processed done
# Processing loop 1464
# merge text
# 0.15100884437561035
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 834.4792070388794
# replace entities done
# step 2
# Processing 74414 sentences
# 1182.9397976398468
# Word processed done
# Processing loop 1465
# merge text
# 0.03500199317932129
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 936.6119050979614
# replace entities done
# step 2
# Processing 74446 sentences
# 1409.3413083553314
# Word processed done
# Processing loop 1466
# merge text
# 0.28002023696899414
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1200.4155685901642
# replace entities done
# step 2
# Processing 73827 sentences
# 1383.537110567093
# Word processed done
# Processing loop 1467
# merge text
# 0.11200666427612305
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 899.320561170578
# replace entities done
# step 2
# Processing 76454 sentences
# 1270.6759264469147
# Word processed done
# Processing loop 1468
# merge text
# 0.0760042667388916
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 767.1250116825104
# replace entities done
# step 2
# Processing 74667 sentences
# 1291.887717962265
# Word processed done
# Processing loop 1469
# merge text
# 0.08000445365905762
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 749.5823748111725
# replace entities done
# step 2
# Processing 73664 sentences
# 1255.6867990493774
# Word processed done
# Processing loop 1470
# merge text
# 0.09300518035888672
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 825.9106779098511
# replace entities done
# step 2
# Processing 75157 sentences
# 1243.881374835968
# Word processed done
# Processing loop 1471
# merge text
# 0.06000328063964844
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 861.9626932144165
# replace entities done
# step 2
# Processing 75071 sentences
# 1389.008698940277
# Word processed done
# Processing loop 1472
# merge text
# 0.2830162048339844
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 864.5437667369843
# replace entities done
# step 2
# Processing 75685 sentences
# 1234.376990556717
# Word processed done
# Processing loop 1473
# merge text
# 0.14200806617736816
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 867.8263449668884
# replace entities done
# step 2
# Processing 76744 sentences
# 1247.9866993427277
# Word processed done
# Processing loop 1474
# merge text
# 0.14400815963745117
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 823.6344079971313
# replace entities done
# step 2
# Processing 74491 sentences
# 1249.684071779251
# Word processed done
# Processing loop 1475
# merge text
# 0.07800459861755371
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 764.8611426353455
# replace entities done
# step 2
# Processing 73603 sentences
# 1295.5720899105072
# Word processed done
# Processing loop 1476
# merge text
# 0.06400394439697266
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 722.6414906978607
# replace entities done
# step 2
# Processing 72881 sentences
# 1311.5990054607391
# Word processed done
# Processing loop 1477
# merge text
# 0.03200173377990723
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 515.07563829422
# replace entities done
# step 2
# Processing 50900 sentences
# 1017.8443922996521
# Word processed done
# Processing loop 1478
# merge text
# 0.024001359939575195
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 461.4647741317749
# replace entities done
# step 2
# Processing 44818 sentences
# 692.2146182060242
# Word processed done
# Processing loop 1479
# merge text
# 0.021001338958740234
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 691.4568450450897
# replace entities done
# step 2
# Processing 52226 sentences
# 863.3456485271454
# Word processed done
# Processing loop 1480
# merge text
# 0.027001619338989258
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 509.2743377685547
# replace entities done
# step 2
# Processing 50946 sentences
# 949.6802275180817
# Word processed done
# Processing loop 1481
# merge text
# 0.029001712799072266
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 570.1230645179749
# replace entities done
# step 2
# Processing 52532 sentences
# 988.3380234241486
# Word processed done
# Processing loop 1482
# merge text
# 0.11700654029846191
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 961.8217649459839
# replace entities done
# step 2
# Processing 75766 sentences
# 1525.3858909606934
# Word processed done
# Processing loop 1483
# merge text
# 0.19052410125732422
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 880.85533618927
# replace entities done
# step 2
# Processing 76547 sentences
# 1650.6782791614532
# Word processed done
# Processing loop 1484
# merge text
# 0.12001371383666992
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 874.9976544380188
# replace entities done
# step 2
# Processing 73944 sentences
# 1505.296189069748
# Word processed done
# Processing loop 1485
# merge text
# 0.06800365447998047
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 779.339352607727
# replace entities done
# step 2
# Processing 67903 sentences
# 1209.2141938209534
# Word processed done
# Processing loop 1486
# merge text
# 0.08751130104064941
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 884.2197313308716
# replace entities done
# step 2
# Processing 75916 sentences
# 1480.6412444114685
# Word processed done
# Processing loop 1487
# merge text
# 0.05500316619873047
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 784.0096435546875
# replace entities done
# step 2
# Processing 69419 sentences
# 1371.8506298065186
# Word processed done
# Processing loop 1488
# merge text
# 0.09000515937805176
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 844.4596202373505
# replace entities done
# step 2
# Processing 72720 sentences
# 3622.7948710918427
# Word processed done
# Processing loop 1489
# merge text
# 0.1845235824584961
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 938.4707164764404
# replace entities done
# step 2
# Processing 71234 sentences
# 3171.2530007362366
# Word processed done
# Processing loop 1490
# merge text
# 0.04650592803955078
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1020.6749649047852
# replace entities done
# step 2
# Processing 62499 sentences
# 2193.1306614875793
# Word processed done
# Processing loop 1491
# merge text
# 0.06850647926330566
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 725.6308991909027
# replace entities done
# step 2
# Processing 60798 sentences
# 1934.468228816986
# Word processed done
# Processing loop 1492
# merge text
# 0.10201025009155273
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 764.9740204811096
# replace entities done
# step 2
# Processing 72164 sentences
# 1263.9854130744934
# Word processed done
# Processing loop 1493
# merge text
# 0.0725090503692627
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 743.4465172290802
# replace entities done
# step 2
# Processing 73112 sentences
# 1438.1720263957977
# Word processed done
# Processing loop 1494
# merge text
# 0.05300450325012207
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 772.5828318595886
# replace entities done
# step 2
# Processing 74378 sentences
# 1260.3885169029236
# Word processed done
# Processing loop 1495
# merge text
# 0.09600520133972168
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 793.2784614562988
# replace entities done
# step 2
# Processing 73959 sentences
# 1235.8032186031342
# Word processed done
# Processing loop 1496
# merge text
# 0.0890052318572998
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 870.0466151237488
# replace entities done
# step 2
# Processing 78436 sentences
# 1469.6278417110443
# Word processed done
# Processing loop 1497
# merge text
# 0.14200806617736816
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 975.3642663955688
# replace entities done
# step 2
# Processing 75147 sentences
# 1242.1155362129211
# Word processed done
# Processing loop 1498
# merge text
# 0.039002418518066406
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 630.2724225521088
# replace entities done
# step 2
# Processing 55094 sentences
# 936.5291843414307
# Word processed done
# Processing loop 1499
# merge text
# 0.054003000259399414
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 804.1172223091125
# replace entities done
# step 2
# Processing 74841 sentences
# 1290.906858921051
# Word processed done
# Processing loop 1500
# merge text
# 0.11600637435913086
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 805.570075750351
# replace entities done
# step 2
# Processing 73333 sentences
# 1275.7174711227417
# Word processed done
# Processing loop 1501
# merge text
# 0.18101048469543457
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 854.310750246048
# replace entities done
# step 2
# Processing 76773 sentences
# 1316.5969293117523
# Word processed done
# Processing loop 1502
# merge text
# 0.21701264381408691
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 853.1678535938263
# replace entities done
# step 2
# Processing 73415 sentences
# 1233.025855064392
# Word processed done
# Processing loop 1503
# merge text
# 0.06900382041931152
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 882.6776206493378
# replace entities done
# step 2
# Processing 75683 sentences
# 1428.9660065174103
# Word processed done
# Processing loop 1504
# merge text
# 0.16000938415527344
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 992.4493379592896
# replace entities done
# step 2
# Processing 74798 sentences
# 1274.728734254837
# Word processed done
# Processing loop 1505
# merge text
# 0.12401151657104492
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 795.4227838516235
# replace entities done
# step 2
# Processing 70331 sentences
# 1387.3735415935516
# Word processed done
# Processing loop 1506
# merge text
# 0.12500691413879395
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 954.374519109726
# replace entities done
# step 2
# Processing 74215 sentences
# 1703.31156539917
# Word processed done
# Processing loop 1507
# merge text
# 0.22101259231567383
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1202.593691110611
# replace entities done
# step 2
# Processing 73927 sentences
# 1920.8854732513428
# Word processed done
# Processing loop 1508
# merge text
# 0.14001774787902832
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1146.8292210102081
# replace entities done
# step 2
# Processing 73175 sentences
# 3527.2981469631195
# Word processed done
# Processing loop 1509
# merge text
# 0.04450559616088867
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 964.80224609375
# replace entities done
# step 2
# Processing 62468 sentences
# 3125.009565114975
# Word processed done
# Processing loop 1510
# merge text
# 0.184523344039917
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 956.8818228244781
# replace entities done
# step 2
# Processing 74894 sentences
# 3380.1673142910004
# Word processed done
# Processing loop 1511
# merge text
# 0.2875344753265381
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1045.5549504756927
# replace entities done
# step 2
# Processing 74490 sentences
# 3284.263625383377
# Word processed done
# Processing loop 1512
# merge text
# 0.16952157020568848
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1172.1006891727448
# replace entities done
# step 2
# Processing 79583 sentences
# 2874.0155839920044
# Word processed done
# Processing loop 1513
# merge text
# 0.23002386093139648
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 944.0891742706299
# replace entities done
# step 2
# Processing 74453 sentences
# 2795.4324815273285
# Word processed done
# Processing loop 1514
# merge text
# 0.07800459861755371
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 845.0166697502136
# replace entities done
# step 2
# Processing 73790 sentences
# 1325.765590429306
# Word processed done
# Processing loop 1515
# merge text
# 0.09100532531738281
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 799.5694828033447
# replace entities done
# step 2
# Processing 73615 sentences
# 1458.2599468231201
# Word processed done
# Processing loop 1516
# merge text
# 0.12700724601745605
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 765.0531282424927
# replace entities done
# step 2
# Processing 75690 sentences
# 1883.0721962451935
# Word processed done
# Processing loop 1517
# merge text
# 0.12200713157653809
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 756.0139422416687
# replace entities done
# step 2
# Processing 73076 sentences
# 1481.0350408554077
# Word processed done
# Processing loop 1518
# merge text
# 0.06000351905822754
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 727.9372379779816
# replace entities done
# step 2
# Processing 72693 sentences
# 1654.3930130004883
# Word processed done
# Processing loop 1519
# merge text
# 0.09800553321838379
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 639.936362028122
# replace entities done
# step 2
# Processing 62242 sentences
# 1233.3859467506409
# Word processed done
# Processing loop 1520
# merge text
# 0.03400158882141113
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 744.2926530838013
# replace entities done
# step 2
# Processing 73986 sentences
# 1396.6103672981262
# Word processed done
# Processing loop 1521
# merge text
# 0.029001712799072266
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 583.5928478240967
# replace entities done
# step 2
# Processing 57201 sentences
# 1035.8975322246552
# Word processed done
# Processing loop 1522
# merge text
# 0.12500715255737305
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 825.2914800643921
# replace entities done
# step 2
# Processing 70699 sentences
# 1240.3733913898468
# Word processed done
# Processing loop 1523
# merge text
# 0.19352459907531738
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 929.0888710021973
# replace entities done
# step 2
# Processing 77290 sentences
# 1532.1698565483093
# Word processed done
# Processing loop 1524
# merge text
# 0.09901261329650879
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 800.2071313858032
# replace entities done
# step 2
# Processing 75907 sentences
# 1288.7454645633698
# Word processed done
# Processing loop 1525
# merge text
# 0.11500668525695801
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 799.8586473464966
# replace entities done
# step 2
# Processing 74407 sentences
# 1431.2924160957336
# Word processed done
# Processing loop 1526
# merge text
# 0.062003374099731445
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 771.7758491039276
# replace entities done
# step 2
# Processing 73768 sentences
# 1325.368791103363
# Word processed done
# Processing loop 1527
# merge text
# 0.10400581359863281
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 746.1862726211548
# replace entities done
# step 2
# Processing 73921 sentences
# 1336.1699686050415
# Word processed done
# Processing loop 1528
# merge text
# 0.06800389289855957
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 783.646005153656
# replace entities done
# step 2
# Processing 76603 sentences
# 1549.7702984809875
# Word processed done
# Processing loop 1529
# merge text
# 0.1410081386566162
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 817.0668511390686
# replace entities done
# step 2
# Processing 76145 sentences
# 1889.4103662967682
# Word processed done
# Processing loop 1530
# merge text
# 0.20701193809509277
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 873.3656642436981
# replace entities done
# step 2
# Processing 76298 sentences
# 1269.6572043895721
# Word processed done
# Processing loop 1531
# merge text
# 0.04000234603881836
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 887.5116217136383
# replace entities done
# step 2
# Processing 72605 sentences
# 1197.2668285369873
# Word processed done
# Processing loop 1532
# merge text
# 0.11700701713562012
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 926.9844000339508
# replace entities done
# step 2
# Processing 75370 sentences
# 1252.0041522979736
# Word processed done
# Processing loop 1533
# merge text
# 0.0630037784576416
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 891.4629237651825
# replace entities done
# step 2
# Processing 75649 sentences
# 1258.4086225032806
# Word processed done
# Processing loop 1534
# merge text
# 0.10700201988220215
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 793.4209654331207
# replace entities done
# step 2
# Processing 71218 sentences
# 1205.0986602306366
# Word processed done
# Processing loop 1535
# merge text
# 0.08900189399719238
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 882.680502653122
# replace entities done
# step 2
# Processing 75469 sentences
# 1253.9832835197449
# Word processed done
# Processing loop 1536
# merge text
# 0.07000374794006348
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 873.8847513198853
# replace entities done
# step 2
# Processing 71757 sentences
# 1186.4942059516907
# Word processed done
# Processing loop 1537
# merge text
# 0.0390012264251709
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 608.8439884185791
# replace entities done
# step 2
# Processing 53667 sentences
# 947.1682457923889
# Word processed done
# Processing loop 1538
# merge text
# 0.019999980926513672
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 530.5900959968567
# replace entities done
# step 2
# Processing 52891 sentences
# 915.7637069225311
# Word processed done
# Processing loop 1539
# merge text
# 0.020000219345092773
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 589.4383819103241
# replace entities done
# step 2
# Processing 51683 sentences
# 872.3995859622955
# Word processed done
# Processing loop 1540
# merge text
# 0.03000020980834961
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 567.5801033973694
# replace entities done
# step 2
# Processing 53024 sentences
# 951.2198874950409
# Word processed done
# Processing loop 1541
# merge text
# 0.02750086784362793
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 559.5675690174103
# replace entities done
# step 2
# Processing 54959 sentences
# 1132.881279706955
# Word processed done
# Processing loop 1542
# merge text
# 0.05000019073486328
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 783.69127202034
# replace entities done
# step 2
# Processing 72735 sentences
# 1396.6149480342865
# Word processed done
# Processing loop 1543
# merge text
# 0.09200382232666016
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 790.1021208763123
# replace entities done
# step 2
# Processing 75250 sentences
# 1308.4624457359314
# Word processed done
# Processing loop 1544
# merge text
# 0.0690007209777832
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 796.0473222732544
# replace entities done
# step 2
# Processing 76088 sentences
# 1483.6437468528748
# Word processed done
# Processing loop 1545
# merge text
# 0.03300070762634277
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 779.3983418941498
# replace entities done
# step 2
# Processing 74205 sentences
# 1298.1288290023804
# Word processed done
# Processing loop 1546
# merge text
# 0.13000035285949707
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 798.8167932033539
# replace entities done
# step 2
# Processing 75071 sentences
# 1308.5427875518799
# Word processed done
# Processing loop 1547
# merge text
# 0.07999992370605469
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 793.242161989212
# replace entities done
# step 2
# Processing 74978 sentences
# 1308.4693655967712
# Word processed done
# Processing loop 1548
# merge text
# 0.1170041561126709
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 807.678822517395
# replace entities done
# step 2
# Processing 72884 sentences
# 1694.942543745041
# Word processed done
# Processing loop 1549
# merge text
# 0.12500858306884766
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1093.4609661102295
# replace entities done
# step 2
# Processing 76520 sentences
# 1546.5702166557312
# Word processed done
# Processing loop 1550
# merge text
# 0.13900279998779297
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 969.3889722824097
# replace entities done
# step 2
# Processing 73685 sentences
# 1256.1046493053436
# Word processed done
# Processing loop 1551
# merge text
# 0.14200186729431152
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 983.5671801567078
# replace entities done
# step 2
# Processing 74215 sentences
# 1263.9008424282074
# Word processed done
# Processing loop 1552
# merge text
# 0.09100151062011719
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 990.1794929504395
# replace entities done
# step 2
# Processing 75232 sentences
# 1256.3184967041016
# Word processed done
# Processing loop 1553
# merge text
# 0.07900190353393555
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 960.1256816387177
# replace entities done
# step 2
# Processing 71734 sentences
# 1236.6038920879364
# Word processed done
# Processing loop 1554
# merge text
# 0.07900619506835938
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 903.5002572536469
# replace entities done
# step 2
# Processing 76004 sentences
# 1320.8121042251587
# Word processed done
# Processing loop 1555
# merge text
# 0.08000016212463379
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 845.5595028400421
# replace entities done
# step 2
# Processing 71253 sentences
# 1163.4043819904327
# Word processed done
# Processing loop 1556
# merge text
# 0.030001163482666016
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 644.3915829658508
# replace entities done
# step 2
# Processing 57825 sentences
# 970.1072103977203
# Word processed done
# Processing loop 1557
# merge text
# 0.04100203514099121
# merge text done
# step 1
# herb
# 0 / 61577
# ...
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1003.7395732402802
# replace entities done
# step 2
# Processing 72155 sentences
# 1453.3187472820282
# Word processed done
# Processing loop 1728
# merge text
# 0.09650683403015137
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 968.238920211792
# replace entities done
# step 2
# Processing 72195 sentences
# 1328.3395307064056
# Word processed done
# Processing loop 1729
# merge text
# 0.046004295349121094
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 933.5759739875793
# replace entities done
# step 2
# Processing 57530 sentences
# 1148.6838846206665
# Word processed done
# Processing loop 1730
# merge text
# 0.1610093116760254
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1186.9369373321533
# replace entities done
# step 2
# Processing 75655 sentences
# 1540.241495847702
# Word processed done
# Processing loop 1731
# merge text
# 0.3780217170715332
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1655.7400720119476
# replace entities done
# step 2
# Processing 75824 sentences
# 1665.6887156963348
# Word processed done
# Processing loop 1732
# merge text
# 0.13401412963867188
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 984.1533825397491
# replace entities done
# step 2
# Processing 78397 sentences
# 1574.8550114631653
# Word processed done
# Processing loop 1733
# merge text
# 0.13100743293762207
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 855.3985817432404
# replace entities done
# step 2
# Processing 75982 sentences
# 1271.072007894516
# Word processed done
# Processing loop 1734
# merge text
# 0.08100342750549316
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 891.5264000892639
# replace entities done
# step 2
# Processing 74131 sentences
# 1388.2641966342926
# Word processed done
# Processing loop 1735
# merge text
# 0.11100602149963379
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1134.6502795219421
# replace entities done
# step 2
# Processing 78547 sentences
# 1595.0882022380829
# Word processed done
# Processing loop 1736
# merge text
# 0.09300518035888672
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 921.5172021389008
# replace entities done
# step 2
# Processing 73720 sentences
# 1282.2978575229645
# Word processed done
# Processing loop 1737
# merge text
# 0.10100722312927246
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1009.0068638324738
# replace entities done
# step 2
# Processing 77295 sentences
# 1492.2785227298737
# Word processed done
# Processing loop 1738
# merge text
# 0.2060232162475586
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1017.6618871688843
# replace entities done
# step 2
# Processing 78221 sentences
# 1416.607663154602
# Word processed done
# Processing loop 1739
# merge text
# 0.08100461959838867
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 915.9823234081268
# replace entities done
# step 2
# Processing 78191 sentences
# 1360.0177018642426
# Word processed done
# Processing loop 1740
# merge text
# 0.03200197219848633
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 754.5344769954681
# replace entities done
# step 2
# Processing 59511 sentences
# 965.8789057731628
# Word processed done
# Processing loop 1741
# merge text
# 0.08300471305847168
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 926.0393462181091
# replace entities done
# step 2
# Processing 75117 sentences
# 1262.4005403518677
# Word processed done
# Processing loop 1742
# merge text
# 0.31401944160461426
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1313.9843714237213
# replace entities done
# step 2
# Processing 78210 sentences
# 1014.199738740921
# Word processed done
# Processing loop 1743
# merge text
# 0.054003000259399414
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 758.2524790763855
# replace entities done
# step 2
# Processing 76375 sentences
# 970.9158506393433
# Word processed done
# Processing loop 1744
# merge text
# 0.05300307273864746
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 893.2059154510498
# replace entities done
# step 2
# Processing 78116 sentences
# 1085.445895910263
# Word processed done
# Processing loop 1745
# merge text
# 0.11501455307006836
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 902.3139910697937
# replace entities done
# step 2
# Processing 78973 sentences
# 1159.7860934734344
# Word processed done
# Processing loop 1746
# merge text
# 0.07900834083557129
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 807.9801616668701
# replace entities done
# step 2
# Processing 77222 sentences
# 1174.3927648067474
# Word processed done
# Processing loop 1747
# merge text
# 0.04700279235839844
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 878.9222986698151
# replace entities done
# step 2
# Processing 78368 sentences
# 1394.1875019073486
# Word processed done
# Processing loop 1748
# merge text
# 0.04600238800048828
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 953.165444612503
# replace entities done
# step 2
# Processing 77214 sentences
# 1334.998426914215
# Word processed done
# Processing loop 1749
# merge text
# 0.0890049934387207
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1756.2139587402344
# replace entities done
# step 2
# Processing 79030 sentences
# 1326.0207662582397
# Word processed done
# Processing loop 1750
# merge text
# 0.12551450729370117
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1029.3555552959442
# replace entities done
# step 2
# Processing 76975 sentences
# 1295.536521911621
# Word processed done
# Processing loop 1751
# merge text
# 0.08600664138793945
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 756.7120280265808
# replace entities done
# step 2
# Processing 59847 sentences
# 1024.885976076126
# Word processed done
# Processing loop 1752
# merge text
# 0.10150766372680664
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 950.7933013439178
# replace entities done
# step 2
# Processing 76772 sentences
# 1366.2069444656372
# Word processed done
# Processing loop 1753
# merge text
# 0.06700372695922852
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 850.3081169128418
# replace entities done
# step 2
# Processing 77212 sentences
# 1341.574936389923
# Word processed done
# Processing loop 1754
# merge text
# 0.029001474380493164
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 754.3897774219513
# replace entities done
# step 2
# Processing 58928 sentences
# 1007.010632276535
# Word processed done
# Processing loop 1755
# merge text
# 0.0525052547454834
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 836.4443624019623
# replace entities done
# step 2
# Processing 60294 sentences
# 977.2910523414612
# Word processed done
# Processing loop 1756
# merge text
# 0.10500597953796387
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1042.1687450408936
# replace entities done
# step 2
# Processing 74983 sentences
# 1297.432254076004
# Word processed done
# Processing loop 1757
# merge text
# 0.15700888633728027
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 947.4077568054199
# replace entities done
# step 2
# Processing 76229 sentences
# 1365.8683366775513
# Word processed done
# Processing loop 1758
# merge text
# 0.0500028133392334
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 876.4887361526489
# replace entities done
# step 2
# Processing 76917 sentences
# 1705.6548194885254
# Word processed done
# Processing loop 1759
# merge text
# 0.11351418495178223
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 774.9202256202698
# replace entities done
# step 2
# Processing 75040 sentences
# 1444.427161693573
# Word processed done
# Processing loop 1760
# merge text
# 0.12400698661804199
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 789.4547274112701
# replace entities done
# step 2
# Processing 76328 sentences
# 1466.864827156067
# Word processed done
# Processing loop 1761
# merge text
# 0.1370077133178711
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1125.2474749088287
# replace entities done
# step 2
# Processing 74520 sentences
# 1598.0643496513367
# Word processed done
# Processing loop 1762
# merge text
# 0.04000234603881836
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 812.1117081642151
# replace entities done
# step 2
# Processing 72248 sentences
# 1691.7699835300446
# Word processed done
# Processing loop 1763
# merge text
# 0.07800459861755371
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 905.1335043907166
# replace entities done
# step 2
# Processing 76897 sentences
# 1994.9976270198822
# Word processed done
# Processing loop 1764
# merge text
# 0.1280074119567871
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 825.2302961349487
# replace entities done
# step 2
# Processing 76236 sentences
# 1545.8778512477875
# Word processed done
# Processing loop 1765
# merge text
# 0.08600497245788574
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 897.2930183410645
# replace entities done
# step 2
# Processing 74647 sentences
# 1903.2339856624603
# Word processed done
# Processing loop 1766
# merge text
# 0.05700325965881348
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 921.0015370845795
# replace entities done
# step 2
# Processing 76566 sentences
# 1770.7669360637665
# Word processed done
# Processing loop 1767
# merge text
# 0.09900569915771484
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 842.6019716262817
# replace entities done
# step 2
# Processing 77133 sentences
# 1802.332905292511
# Word processed done
# Processing loop 1768
# merge text
# 0.1480083465576172
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 854.2261672019958
# replace entities done
# step 2
# Processing 75599 sentences
# 1519.3705050945282
# Word processed done
# Processing loop 1769
# merge text
# 0.1780102252960205
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1374.2573173046112
# replace entities done
# step 2
# Processing 73751 sentences
# 1363.1465322971344
# Word processed done
# Processing loop 1770
# merge text
# 0.11000633239746094
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1162.4703118801117
# replace entities done
# step 2
# Processing 83240 sentences
# 1792.9767997264862
# Word processed done
# Processing loop 1771
# merge text
# 0.19401121139526367
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1024.0981435775757
# replace entities done
# step 2
# Processing 74419 sentences
# 1461.7227160930634
# Word processed done
# Processing loop 1772
# merge text
# 0.12700748443603516
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1012.9165518283844
# replace entities done
# step 2
# Processing 77709 sentences
# 1495.0127482414246
# Word processed done

# %%
textdict = []

# %%
########### Make outdir
#os.system('mkdir "..//data//clean_data//only_noun"')
#os.system('mkdir "..//data//clean_data//only_entity"')
#os.system('mkdir "..//data//clean_data//without_adjective"')
#os.system('mkdir "..//data//clean_data//full_sentence"')
os.system('mkdir "..//data//clean_data//noun_verb"')
########### Text source
#text_list = os.listdir('..//data/preprocessing/text_extract/')
text_list = os.listdir('..//data/abstract_full/')[:]
#text_list = ['abtract_list_26.json']
count = 0
track = 0
#replaced_list = []
textdict = []
#for file in text_list :
#for i in range(len(text_list)) :
while text_list != [] :
    #####
    start = 0
    if len(text_list) > 5 :
        for num in range(5) :
            if start == 0 :
                #textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
                textdict = json.load(open('..//data/abstract_full/%s'%text_list[num]))
                start = 1
            else :
                textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
        [text_list.pop(0) for i in range(5)]
    else :
        for num in range(len(text_list)) :
            if start == 0 :
                #textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
                textdict = json.load(open('..//data//abstract_full/%s'%text_list[num]))
                start = 1
            else :
                textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
        [text_list.pop(0) for i in range(len(text_list))]
    #####
    print('Processing loop %s'%track)
    text = rmv_n(textdict)
    textdict = []
    #####
    print('step 1')
    (text,replaced_list) = entity_replace(text,replaced_list)
    #####
    print('step 2')
    sentences_processed = word_processing(text,track,stop_words,punctuations)
    text = ''
    #####
    ##### 
    track+=1

#########


#####
#entity_replaced.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-035601df330d> in <module>()
#      25                 start = 1
#      26             else :
# ---> 27                 textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
#      28         [text_list.pop(0) for i in range(5)]
#      29     else :
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'dict'

# %%
########### Text source
#text_list = os.listdir('..//data/preprocessing/text_extract/')
text_list = ['text_extract_100.json']
count = 0
track = 0
replaced_list = []
textdict = []
for file in text_list :
    if count == 0 :
        textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
        count+=1
    elif count < 8 :
        textdict.update(json.load(open('..//data//preprocessing//text_extract//%s'%file)))
        count+=1
    elif count == 8 :
        textdict.update(json.load(open('..//data//preprocessing//text_extract//%s'%file)))
        count = 0
        #####
        print('Processing loop %s'%track)
        text = rmv_n(textdict)
        textdict = []
        #####
        print('step 1')
        (text,replaced_list) = entity_replace(text,replaced_list)
        #####
        print('step 2')
        sentences_processed = word_processing(text)
        text = ''
        #####
        ##### List of processed sentences
        outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
        outfile.write(json.dumps(sentences_processed))
        outfile.close()
        track+=1
        sentences_processed = []
        
#########
print('Processing loop %s'%track)
text = rmv_n(textdict)
textdict = []
#####
print('step 1')
(text,replaced_list) = entity_replace(text,replaced_list)
#####
print('step 2')
sentences_processed = word_processing(text)
text = ''
#####
##### List of processed sentences
outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
outfile.write(json.dumps(sentences_processed))
outfile.close()

#####
entity_replaced.close()
# Out:
# Processing loop 0
# merge text
# 0.1980113983154297
# merge text done
# step 1
# herb
# 0 / 30820
# 1000 / 30820
# 2000 / 30820
# 3000 / 30820
# 4000 / 30820
# 5000 / 30820
# 6000 / 30820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-ceb61dfe55b6> in <module>()
#      41 #####
#      42 print('step 1')
# ---> 43 (text,replaced_list) = entity_replace(text,replaced_list)
#      44 #####
#      45 print('step 2')
#
# <ipython-input-121-9617de803cfa> in entity_replace(text, replaced_list)
#      15         if count % 1000 == 0 :
#      16             print('%s / %s'%(count,len(herb_entity)))
# ---> 17         count+=1
#      18     print('herb done')
#      19
#
# KeyboardInterrupt:

# %%
entity_replaced.close()
