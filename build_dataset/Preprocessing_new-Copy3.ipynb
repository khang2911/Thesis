# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import nltk
import json
import os
import sys
import time
import operator
#import re
import string
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
###########
ps = PorterStemmer()

# %%
########### Set up Output File
outdir = '..//data//clean_data'

##### Contain 2 column : 1. Replaced name of entity / 2. Real name of entity
reverse_entity = open(os.path.join(outdir,os.path.basename('entity_total.csv')),'w',encoding='utf-8') 

#####
#entity_replaced = open(os.path.join(outdir,os.path.basename('entity_replaced_4.csv')),'w',encoding='utf-8')

# %%
########### Trigger word
triggers_raw = open('..//data//preprocessing/triggers.txt').read().split('\n')[:-1]
triggers = []
for row in triggers_raw :
    triggers.append(ps.stem(row.split('\t')[-1]))
    
triggers = list(set(triggers))

# %%
########### Entity sources

#### Drug synonyms from drugbank
#drugs = json.load(open('..//data/preprocessing/drug_corpus/drug_name_synonyms.json',encoding='utf-8'))
drugs = json.load(open('..//data/preprocessing/drug_corpus/drugs.json',encoding='utf-8'))
#### Herb scientific name and its synonyms (not alias)
#herbs = json.load(open('..//data/preprocessing/herb_corpus/herb_science_synonyms.json',encoding='utf-8'))
herbs = json.load(open('..//data/preprocessing/herb_corpus/herb_syms_total.json',encoding='utf-8'))
#### standard ref without effect
ref_without = json.load(open('..//data/preprocessing/standard_ref/standard_ref_without_effect.json',encoding='utf-8'))

#### standard ref with effect
#ref_effect = open('..//data/preprocessing/standard_ref/standard_ref_effect.csv').read().split('\n')[:-1]

#### Adverse effect corpus
#adverse_effect = json.load(open('..//data/preprocessing/adverse_effect_corpus/adverse_effect.json'))

# %%
########## Create name for entity

###### trigger entity
#trigger_entity = {}
#for each in triggers :
#    trigger_entity[each] = 'trigger_entity'
#    reverse_entity.write('trigger_entity\t%s\n'%each)

###### Drug entity
drug_entity = {}
drugorder = 0
for ID in drugs :
    for drug in drugs[ID] :
        if drug.lower() in herbs or drug.lower() in ref_without :
            break
        drug_entity[drug.lower()] = 'drug_entity_%s'%drugorder
        try :
            reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drug.lower()))
        except :
            drugencode = str(drug.lower()).encode('utf8')
            reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drugencode))
    drugorder+=1

###### Herb entity 
herb_entity = {}
herborder = 0
for herb in herbs :
    #herb_entity[herb.lower()] = 'herb_entity_%s'%herborder
    reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herb.lower()))
    for synonym in herbs[herb] :
        herb_entity[synonym.lower()] = 'herb_entity_%s'%herborder
        try :
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,synonym.lower()))
        except :
            herbencode = str(synonym.lower()).encode('utf8')
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herbencode))
    herborder+=1
    
###### Adverse effect entity
#effect_entity = {}
#effectorder = 0
#for each in adverse_effect :
#    effect_entity[each.lower()] = 'EF_entity_%s'%effectorder
#    try :
#        reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,each.lower()))
#    except :
#        effectencode = str(each.lower()).encode('utf8')
#        reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#    effectorder+=1
    
###### standard ref without effect entity 
for herb in ref_without :
    if herb.lower() not in herb_entity :
        herb_entity[herb.lower()] = 'herb_entity_%s'%herborder
        try :
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herb.lower()))
        except :
            herbencode = str(herb.lower()).encode('utf8')
            reverse_entity.write('herb_entity_%s\t%s\n'%(herborder,herbencode))
        herborder+=1
    for drug in ref_without[herb] :
        if drug.lower() not in drug_entity :
            drug_entity[drug.lower()] = 'drug_entity_%s'%drugorder
            try :
                reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drug.lower()))
            except :
                drugencode = str(drug.lower()).encode('utf8')
                reverse_entity.write('drug_entity_%s\t%s\n'%(drugorder,drugencode))
            drugorder+=1
            
###### standard ref with effect
''''''
#for row in ref_effect :
#    effect = row.split('\t')[2]
#    ###
#    if effect.lower() not in effect_entity :
#        effect_entity[effect.lower()] = 'EF_entity_%s'%effectorder
#        try :
#            reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effect.lower()))
#        except :
#            effectencode = str(effect.lower()).encode('utf8')
#            reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#        effectorder+=1
#    ###    
#    if len(row.split('\t')) == 4 :
#        effect1 = row.split('\t')[3]
#        if effect1.lower() not in effect_entity :
#            effect_entity[effect1.lower()] = 'EF_entity_%s'%effectorder
#            try :
#                reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effect1.lower()))
#            except :
#                effectencode = str(effect1.lower()).encode('utf8')
#                reverse_entity.write('EF_entity_%s\t%s\n'%(effectorder,effectencode))
#            effectorder+=1
''''''
######
reverse_entity.close()

# %%
###### remove '\n' from text and merge text
def rmv_n(textdict) :
    begin = time.time()
    text = ''
    print('merge text')
    count = 0
    for each in textdict :
        if len(textdict[each].split('\n')) != 1 :
            new = ''.join(textdict[each].split('\n'))
            text+=new
        else:
            text+= textdict[each]
        if count % 1000 == 0 :
            print('%s / %s'%(count,len(textdict)))
        count+=1
    text = text.lower()
    print(time.time() - begin)
    print('merge text done')
    return text

# %%
###### remove '\n' from text and merge text
def rmv_n(textdict) :
    begin = time.time()
    text = ''
    print('merge text')

    #text = ''.join(''.join(operator.itemgetter(*list(textdict))(textdict)).split('\n')).lower()
    
    #text = ''.join(''.join([textdict[x] for x in list(textdict)]).split('\n')).lower()
    #text =  ''.join([''.join(x.split('\n')) for sublist in textdict for x in sublist ])
    text = ''.join([textdict[x].replace('\n',' ') for x in list(textdict)])
    print(time.time() - begin)
    print('merge text done')
    return text

# %%
###### Entity replacement
def entity_replace(text) :
    ###
    begin = time.time()
    ###
    count = 0
    print('herb')
    for herb in herb_entity :
        if herb in text :
            text = text.replace(' %s '%herb,' %s '%herb_entity[herb])
            #re.sub(herb,herb_entity[herb],text)
            #if herb not in replaced_list :
                #entity_replaced.write('%s\t%s\n'%(herb_entity[herb],herb))
                #replaced_list.append(herb)
        if count % 10000 == 0 :
            print('%s / %s'%(count,len(herb_entity)))
        count+=1
    print('herb done')
    
    ###
    drug_entity_single = {}
    count = 0
    print('drug')
    for drug in drug_entity :
        if drug in text :
            text = text.replace(' %s '%drug,' %s '%drug_entity[drug])
            #re.sub(drug,drug_entity[drug],text)
            #if drug not in replaced_list :
                #entity_replaced.write('%s\t%s\n'%(drug_entity[drug],drug))
                #replaced_list.append(drug)
        #else:
            #drug_entity_single[drug] = drug_entity[drug]
        if count % 10000 == 0 :
            print('%s / %s'%(count,len(drug_entity)))
        count+=1
    print('drug done')
    ###
#    print('effect')
#    count = 0
#    for effect in effect_entity :
#        if effect in text :
#            text = text.replace(effect,' %s '%effect_entity[effect])
#            #re.sub(effect,effect_entity[effect],text)
#            if effect not in replaced_list :
#                entity_replaced.write('%s\t%s\n'%(effect_entity[effect],effect))
#                replaced_list.append(effect)
#        if count % 1000 == 0 :
#            print('%s / %s'%(count,len(drug_entity)))
#        count+=1
#    print('effect done')
    ###
#    for trig in trigger_entity:
#        if trig in text:
#            text = text.replace(trig,' %s '%trigger_entity[trig])
            #re.sub(trig,trigger_entity[trig],text)
#            if trig not in replaced_list :
#                entity_replaced.write('%s\t%s\n'%(trigger_entity[trig],trig))
#                replaced_list.append(effect)
#    print('trigger done')
    print(time.time() - begin)
    print('replace entities done')
    return text

# %%
a = [[1,2,3,4],[4,5,6,7],[3,4,5,6]]
b = [4,5,6,7]
c = [3,4,5,6]

[ [ i for i in each if i in b and i in c ] for each in a]
# Out:
# [[4], [4, 5, 6], [4, 5, 6]]

# %%
######## word processing and word removal
#stop_words = list(set(stopwords.words('english')))
#punctuations = string.punctuation

stop_and_punctuations = list(set(stopwords.words('english'))) + [i for i in string.punctuation ]


def word_processing(text,track,stop_and_punctuations) :
    begin = time.time()
    count = 0
    #outdir = '..//data//clean_data//noun_verb'
    outdir = '..//data//clean_data//'
    subtrack = 0
    ######
    Pos_accept = ['N','V']
    
    ###### Split text into words
    #words = nltk.pos_tag(word_tokenize(text))
    #text = ''
    sentences = [ x for x in TextBlob(text).sentences if len(x.split()) > 3 ]
    total = len(sentences)
    print('Processing %s sentences'%total)
    #######
    sentences_noun_verb = []
    ########
    sentence_noun_verb = []
    ###### Processing
    sentences_noun_verb = [ [word[0] for word in sentence.tags if word[1][0] in Pos_accept and word[0] not in stop_and_punctuations ]  for sentence in sentences ]
    
    ##### 
    print(time.time() - begin)
    print('Word processed done')

    ##### Noun verb
    #outdir = '..//data//clean_data//noun_verb'
    outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
    outfile.write(json.dumps(sentences_noun_verb))
    outfile.close()
    sentences_noun_verb = []

# %%
######## word processing and word removal
def word_processing(text) :
    begin = time.time()
    count = 0

    ###### Create pos_tag accept list and stop words list 
    stop_words = list(set(stopwords.words('english')))
    pos_tag_accept = ['NN','NNS','NNP','NNPS','VB','VBD','VBG','VBN','VBP','VBZ']

    ###### Create entity list 
    reverse_entity = open('..//data/clean_data/entity_total.csv').read().split('\n')[:-1]
    entity_list = []
    for row in reverse_entity :
        entity_list.append(row.split('\t')[0])

    entity_list = list(set(entity_list))

    ###### Split text into sentences
    sentences = TextBlob(text).sentences
    total = len(sentences)
    print('Processing %s sentences'%total)
    sentences_processed = []

    ###### Processing
    for sentence in sentences :          
        words = word_tokenize(str(sentence)) ##### Split sentence into words 
        #####
        if len(set(words).intersection(entity_list)) > 2 : ##### Choose sentence contain more than 2 entities
            for word in words :
                if word in stop_words : ##### Remove stop words
                    words.pop(words.index(word))
                elif len(word) == 1 : ##### Remove punctuation marks
                    words.pop(words.index(word))    
            ###
            tags = nltk.pos_tag(words)
            for tag in tags :
                if tag[0] in entity_list : ##### Save entities
                    pass      
                elif tag[1] not in pos_tag_accept : ##### Remove words which are not noun,verb, and adjective 
                    words.pop(words.index(tag[0]))
            ###
            if len(words) > 3 : ###### Save processed sentence
                sentences_processed.append(words)
        ###
        if count % 10000 == 0 :
            print('Processed %s sentences'%count)
        count+=1

    ##### 
    print(time.time() - begin)
    print('Word processed done')
    return sentences_processed

# %%
len(os.listdir('..//data/abstract_full/')
# Out:
# 60

# %%
########### Make outdir
os.system('mkdir "..//data//clean_data//noun_verb"')
########### Text source
text_list = os.listdir('..//data/abstract_full_1/')[1057:1420]
#text_list = ['abstract_00.json']
count = 0
track = 1057
#replaced_list = []
textdict = {}
#for file in text_list :
#for i in range(len(text_list)) :
for file in text_list :
    textdict = json.load(open('../data/abstract_full_1/%s'%file))
    #####
    print('Processing loop %s'%track)
    text = rmv_n(textdict).lower()
    textdict = []
    #####
    print('step 1')
    text = entity_replace(text)
    #####
    print('step 2')
    sentences_processed = word_processing(text,track,stop_and_punctuations)
    text = ''
    #####
    ##### 
    track+=1

#########


#####
#entity_replaced.close()
# Out:
# Processing loop 1057
# merge text
# 0.03500199317932129
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 838.8902385234833
# replace entities done
# step 2
# Processing 70978 sentences
# 1486.494151353836
# Word processed done
# Processing loop 1058
# merge text
# 0.0370023250579834
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 837.8514475822449
# replace entities done
# step 2
# Processing 75158 sentences
# 1157.1824476718903
# Word processed done
# Processing loop 1059
# merge text
# 0.04100227355957031
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 805.9010977745056
# replace entities done
# step 2
# Processing 74538 sentences
# 1487.718034029007
# Word processed done
# Processing loop 1060
# merge text
# 0.06700563430786133
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 823.9921519756317
# replace entities done
# step 2
# Processing 75178 sentences
# 1461.0044479370117
# Word processed done
# Processing loop 1061
# merge text
# 0.10100555419921875
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 838.4466309547424
# replace entities done
# step 2
# Processing 75239 sentences
# 1420.1676194667816
# Word processed done
# Processing loop 1062
# merge text
# 0.0630033016204834
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 763.2248909473419
# replace entities done
# step 2
# Processing 72063 sentences
# 1382.3024270534515
# Word processed done
# Processing loop 1063
# merge text
# 0.0740044116973877
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 975.9648501873016
# replace entities done
# step 2
# Processing 74464 sentences
# 1479.8682453632355
# Word processed done
# Processing loop 1064
# merge text
# 0.08000826835632324
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 962.7561283111572
# replace entities done
# step 2
# Processing 73868 sentences
# 1372.140368461609
# Word processed done
# Processing loop 1065
# merge text
# 0.07950520515441895
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1086.360446691513
# replace entities done
# step 2
# Processing 73647 sentences
# 1556.4554197788239
# Word processed done
# Processing loop 1066
# merge text
# 0.08400487899780273
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 851.6612050533295
# replace entities done
# step 2
# Processing 61343 sentences
# 1262.6217212677002
# Word processed done
# Processing loop 1067
# merge text
# 0.10100579261779785
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 938.0810005664825
# replace entities done
# step 2
# Processing 58829 sentences
# 988.2108335494995
# Word processed done
# Processing loop 1068
# merge text
# 0.08100485801696777
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 970.5395424365997
# replace entities done
# step 2
# Processing 74287 sentences
# 1189.0217111110687
# Word processed done
# Processing loop 1069
# merge text
# 0.07200407981872559
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 930.043648481369
# replace entities done
# step 2
# Processing 74434 sentences
# 1223.7094979286194
# Word processed done
# Processing loop 1070
# merge text
# 0.10600590705871582
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 947.5217704772949
# replace entities done
# step 2
# Processing 74603 sentences
# 1445.248970746994
# Word processed done
# Processing loop 1071
# merge text
# 0.12000679969787598
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 984.8988301753998
# replace entities done
# step 2
# Processing 73603 sentences
# 1440.0390405654907
# Word processed done
# Processing loop 1072
# merge text
# 0.13800787925720215
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1050.5543112754822
# replace entities done
# step 2
# Processing 77578 sentences
# 1302.0406684875488
# Word processed done
# Processing loop 1073
# merge text
# 0.04500269889831543
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1023.1562461853027
# replace entities done
# step 2
# Processing 74348 sentences
# 1208.269386291504
# Word processed done
# Processing loop 1074
# merge text
# 0.19401121139526367
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 999.6801130771637
# replace entities done
# step 2
# Processing 72839 sentences
# 1150.2273387908936
# Word processed done
# Processing loop 1075
# merge text
# 0.07500457763671875
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 889.3014581203461
# replace entities done
# step 2
# Processing 67163 sentences
# 1058.1407506465912
# Word processed done
# Processing loop 1076
# merge text
# 0.06400370597839355
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 821.621675491333
# replace entities done
# step 2
# Processing 71837 sentences
# 1143.3905351161957
# Word processed done
# Processing loop 1077
# merge text
# 0.05800318717956543
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 910.8432016372681
# replace entities done
# step 2
# Processing 76615 sentences
# 1496.1962358951569
# Word processed done
# Processing loop 1078
# merge text
# 0.09900569915771484
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1196.742769241333
# replace entities done
# step 2
# Processing 72878 sentences
# 1337.2246930599213
# Word processed done
# Processing loop 1079
# merge text
# 0.06600379943847656
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 722.3472456932068
# replace entities done
# step 2
# Processing 55105 sentences
# 884.6827344894409
# Word processed done
# Processing loop 1080
# merge text
# 0.031001806259155273
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 646.7522060871124
# replace entities done
# step 2
# Processing 72096 sentences
# 1198.6977310180664
# Word processed done
# Processing loop 1081
# merge text
# 0.06400346755981445
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 717.8138027191162
# replace entities done
# step 2
# Processing 65562 sentences
# 1096.9073295593262
# Word processed done
# Processing loop 1082
# merge text
# 0.027001380920410156
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 575.2946684360504
# replace entities done
# step 2
# Processing 53911 sentences
# 961.4733600616455
# Word processed done
# Processing loop 1083
# merge text
# 0.049002885818481445
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 679.5212113857269
# replace entities done
# step 2
# Processing 61463 sentences
# 1010.5613031387329
# Word processed done
# Processing loop 1084
# merge text
# 0.06150412559509277
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 849.8217265605927
# replace entities done
# step 2
# Processing 75111 sentences
# 1384.7714319229126
# Word processed done
# Processing loop 1085
# merge text
# 0.24701428413391113
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 849.5168952941895
# replace entities done
# step 2
# Processing 74805 sentences
# 1218.1120357513428
# Word processed done
# Processing loop 1086
# merge text
# 0.05500340461730957
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 855.2966589927673
# replace entities done
# step 2
# Processing 75363 sentences
# 1228.022548675537
# Word processed done
# Processing loop 1087
# merge text
# 0.029001474380493164
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 694.410965681076
# replace entities done
# step 2
# Processing 61944 sentences
# 1016.1034171581268
# Word processed done
# Processing loop 1088
# merge text
# 0.031001806259155273
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 607.1030449867249
# replace entities done
# step 2
# Processing 56657 sentences
# 936.7941219806671
# Word processed done
# Processing loop 1089
# merge text
# 0.04300236701965332
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 728.3200180530548
# replace entities done
# step 2
# Processing 64572 sentences
# 1052.6154038906097
# Word processed done
# Processing loop 1090
# merge text
# 0.07200407981872559
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 857.2199859619141
# replace entities done
# step 2
# Processing 73769 sentences
# 1179.9827387332916
# Word processed done
# Processing loop 1091
# merge text
# 0.05300283432006836
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 644.505010843277
# replace entities done
# step 2
# Processing 71324 sentences
# 1151.3052616119385
# Word processed done
# Processing loop 1092
# merge text
# 0.07800436019897461
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 907.1413583755493
# replace entities done
# step 2
# Processing 70184 sentences
# 1136.1882665157318
# Word processed done
# Processing loop 1093
# merge text
# 0.07700443267822266
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 811.7712738513947
# replace entities done
# step 2
# Processing 72373 sentences
# 1383.5382587909698
# Word processed done
# Processing loop 1094
# merge text
# 0.15800905227661133
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 947.3774576187134
# replace entities done
# step 2
# Processing 73075 sentences
# 1381.4134600162506
# Word processed done
# Processing loop 1095
# merge text
# 0.05700325965881348
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 936.7938325405121
# replace entities done
# step 2
# Processing 72174 sentences
# 1497.201622724533
# Word processed done
# Processing loop 1096
# merge text
# 0.09700560569763184
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 845.0808901786804
# replace entities done
# step 2
# Processing 72275 sentences
# 1454.8797373771667
# Word processed done
# Processing loop 1097
# merge text
# 0.09400677680969238
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 798.7752859592438
# replace entities done
# step 2
# Processing 70115 sentences
# 1329.9661462306976
# Word processed done
# Processing loop 1098
# merge text
# 0.04200243949890137
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 744.7481043338776
# replace entities done
# step 2
# Processing 67176 sentences
# 1290.4261727333069
# Word processed done
# Processing loop 1099
# merge text
# 0.06000375747680664
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 782.095118522644
# replace entities done
# step 2
# Processing 70826 sentences
# 1432.4759232997894
# Word processed done
# Processing loop 1100
# merge text
# 0.0875082015991211
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 769.2017273902893
# replace entities done
# step 2
# Processing 71718 sentences
# 2413.612983226776
# Word processed done
# Processing loop 1101
# merge text
# 0.18901920318603516
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 980.7549166679382
# replace entities done
# step 2
# Processing 70509 sentences
# 2708.393199443817
# Word processed done
# Processing loop 1102
# merge text
# 0.09801244735717773
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 1127.481628894806
# replace entities done
# step 2
# Processing 72686 sentences
# 3126.1751375198364
# Word processed done
# Processing loop 1103
# merge text
# 0.12351560592651367
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 869.715500831604
# replace entities done
# step 2
# Processing 70456 sentences
# 2408.739462852478
# Word processed done
# Processing loop 1104
# merge text
# 0.07650613784790039
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 830.734228849411
# replace entities done
# step 2
# Processing 71022 sentences
# 1392.6370422840118
# Word processed done
# Processing loop 1105
# merge text
# 0.0850076675415039
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 787.343738079071
# replace entities done
# step 2
# Processing 72522 sentences
# 1394.239176273346
# Word processed done
# Processing loop 1106
# merge text
# 0.04200243949890137
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 771.4711430072784
# replace entities done
# step 2
# Processing 74458 sentences
# 1246.918748140335
# Word processed done
# Processing loop 1107
# merge text
# 0.04800295829772949
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 735.9525811672211
# replace entities done
# step 2
# Processing 73363 sentences
# 1286.8884048461914
# Word processed done
# Processing loop 1108
# merge text
# 0.019001007080078125
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 460.9606235027313
# replace entities done
# step 2
# Processing 53055 sentences
# 905.4679844379425
# Word processed done
# Processing loop 1109
# merge text
# 0.04200553894042969
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 702.5983829498291
# replace entities done
# step 2
# Processing 56897 sentences
# 890.015969991684
# Word processed done
# Processing loop 1110
# merge text
# 0.03600192070007324
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 763.4290442466736
# replace entities done
# step 2
# Processing 56878 sentences
# 952.4273850917816
# Word processed done
# Processing loop 1111
# merge text
# 0.02800154685974121
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 538.4031271934509
# replace entities done
# step 2
# Processing 52188 sentences
# 946.7378220558167
# Word processed done
# Processing loop 1112
# merge text
# 0.022001266479492188
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 584.3837432861328
# replace entities done
# step 2
# Processing 56595 sentences
# 1012.4197020530701
# Word processed done
# Processing loop 1113
# merge text
# 0.05500292778015137
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 774.7802140712738
# replace entities done
# step 2
# Processing 73186 sentences
# 1263.3142805099487
# Word processed done
# Processing loop 1114
# merge text
# 0.06900382041931152
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 773.8547039031982
# replace entities done
# step 2
# Processing 71213 sentences
# 1219.6750524044037
# Word processed done
# Processing loop 1115
# merge text
# 0.11400675773620605
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 849.7421894073486
# replace entities done
# step 2
# Processing 75581 sentences
# 1286.7879042625427
# Word processed done
# Processing loop 1116
# merge text
# 0.11701488494873047
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 809.5452394485474
# replace entities done
# step 2
# Processing 70373 sentences
# 1187.3358964920044
# Word processed done
# Processing loop 1117
# merge text
# 0.03500199317932129
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 676.2994425296783
# replace entities done
# step 2
# Processing 54491 sentences
# 1028.96990275383
# Word processed done
# Processing loop 1118
# merge text
# 0.061004638671875
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 715.7730071544647
# replace entities done
# step 2
# Processing 55895 sentences
# 1030.1865916252136
# Word processed done
# Processing loop 1119
# merge text
# 0.05300307273864746
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 673.7474205493927
# replace entities done
# step 2
# Processing 65437 sentences
# 1104.1496119499207
# Word processed done
# Processing loop 1120
# merge text
# 0.044002532958984375
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 713.1697599887848
# replace entities done
# step 2
# Processing 70171 sentences
# 1431.8801355361938
# Word processed done
# Processing loop 1121
# merge text
# 0.11400675773620605
# merge text done
# step 1
# herb
# 0 / 61577
# 10000 / 61577
# 20000 / 61577
# 30000 / 61577
# 40000 / 61577
# 50000 / 61577
# 60000 / 61577
# herb done
# drug
# 0 / 26739
# 10000 / 26739
# 20000 / 26739
# drug done
# 830.086644411087
# replace entities done
# step 2

# %%
textdict = []

# %%
########### Make outdir
#os.system('mkdir "..//data//clean_data//only_noun"')
#os.system('mkdir "..//data//clean_data//only_entity"')
#os.system('mkdir "..//data//clean_data//without_adjective"')
#os.system('mkdir "..//data//clean_data//full_sentence"')
os.system('mkdir "..//data//clean_data//noun_verb"')
########### Text source
#text_list = os.listdir('..//data/preprocessing/text_extract/')
text_list = os.listdir('..//data/abstract_full/')[:]
#text_list = ['abtract_list_26.json']
count = 0
track = 0
#replaced_list = []
textdict = []
#for file in text_list :
#for i in range(len(text_list)) :
while text_list != [] :
    #####
    start = 0
    if len(text_list) > 5 :
        for num in range(5) :
            if start == 0 :
                #textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
                textdict = json.load(open('..//data/abstract_full/%s'%text_list[num]))
                start = 1
            else :
                textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
        [text_list.pop(0) for i in range(5)]
    else :
        for num in range(len(text_list)) :
            if start == 0 :
                #textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
                textdict = json.load(open('..//data//abstract_full/%s'%text_list[num]))
                start = 1
            else :
                textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
        [text_list.pop(0) for i in range(len(text_list))]
    #####
    print('Processing loop %s'%track)
    text = rmv_n(textdict)
    textdict = []
    #####
    print('step 1')
    (text,replaced_list) = entity_replace(text,replaced_list)
    #####
    print('step 2')
    sentences_processed = word_processing(text,track,stop_words,punctuations)
    text = ''
    #####
    ##### 
    track+=1

#########


#####
#entity_replaced.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-035601df330d> in <module>()
#      25                 start = 1
#      26             else :
# ---> 27                 textdict += json.load(open('..//data//abstract_full/%s'%text_list[num]))
#      28         [text_list.pop(0) for i in range(5)]
#      29     else :
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'dict'

# %%
########### Text source
#text_list = os.listdir('..//data/preprocessing/text_extract/')
text_list = ['text_extract_100.json']
count = 0
track = 0
replaced_list = []
textdict = []
for file in text_list :
    if count == 0 :
        textdict = json.load(open('..//data//preprocessing//text_extract//%s'%file))
        count+=1
    elif count < 8 :
        textdict.update(json.load(open('..//data//preprocessing//text_extract//%s'%file)))
        count+=1
    elif count == 8 :
        textdict.update(json.load(open('..//data//preprocessing//text_extract//%s'%file)))
        count = 0
        #####
        print('Processing loop %s'%track)
        text = rmv_n(textdict)
        textdict = []
        #####
        print('step 1')
        (text,replaced_list) = entity_replace(text,replaced_list)
        #####
        print('step 2')
        sentences_processed = word_processing(text)
        text = ''
        #####
        ##### List of processed sentences
        outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
        outfile.write(json.dumps(sentences_processed))
        outfile.close()
        track+=1
        sentences_processed = []
        
#########
print('Processing loop %s'%track)
text = rmv_n(textdict)
textdict = []
#####
print('step 1')
(text,replaced_list) = entity_replace(text,replaced_list)
#####
print('step 2')
sentences_processed = word_processing(text)
text = ''
#####
##### List of processed sentences
outfile = open(os.path.join(outdir,os.path.basename('processed_sentences_%s.json'%track)),'w')
outfile.write(json.dumps(sentences_processed))
outfile.close()

#####
entity_replaced.close()
# Out:
# Processing loop 0
# merge text
# 0.1980113983154297
# merge text done
# step 1
# herb
# 0 / 30820
# 1000 / 30820
# 2000 / 30820
# 3000 / 30820
# 4000 / 30820
# 5000 / 30820
# 6000 / 30820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-ceb61dfe55b6> in <module>()
#      41 #####
#      42 print('step 1')
# ---> 43 (text,replaced_list) = entity_replace(text,replaced_list)
#      44 #####
#      45 print('step 2')
#
# <ipython-input-121-9617de803cfa> in entity_replace(text, replaced_list)
#      15         if count % 1000 == 0 :
#      16             print('%s / %s'%(count,len(herb_entity)))
# ---> 17         count+=1
#      18     print('herb done')
#      19
#
# KeyboardInterrupt:

# %%
entity_replaced.close()
