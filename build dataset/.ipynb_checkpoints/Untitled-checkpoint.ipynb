# %%
import json
import os
path = '..\\data\\id.json'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KHANG\\thesis\\Thesis\\build dataset'

# %%
a = json.load(open(path))

# %%
a
# Out:
# ['5785906',
#  '5749298',
#  '5783490',
#  '5783135',
#  '5774790',
#  '5762627',
#  '5762497',
#  '5762239',
#  '5761055',
#  '5760960',
#  '5760947',
#  '5760777',
#  '5760766',
#  '5797324',
#  '5786858',
#  '5771051',
#  '5762620',
#  '5761360',
#  '5761221',
#  '5761218',
#  '5761012',
#  '5760984',
#  '5760807',
#  '5760786',
#  '5721398',
#  '5686859',
#  '5788051',
#  '5775207',
#  '5773022',
#  '5771072',
#  '5770393',
#  '5775521',
#  '5766630',
#  '5766629',
#  '5766234',
#  '5765031',
#  '5762866',
#  '5761900',
#  '5761194',
#  '5766637',
#  '5766636',
#  '5759299',
#  '5751800',
#  '5771353',
#  '5788220',
#  '5780369',
#  '5758101',
#  '5789313',
#  '5747158',
#  '5747122',
#  '5749554',
#  '5745960',
#  '5745730',
#  '5743680',
#  '5738440',
#  '5738179',
#  '5735878',
#  '5748148',
#  '5750617',
#  '5752900',
#  '5739923',
#  '5736021',
#  '5735979',
#  '5730864',
#  '5733343',
#  '5795599',
#  '5732019',
#  '5748795',
#  '5725837',
#  '5778333',
#  '5751100',
# ...
